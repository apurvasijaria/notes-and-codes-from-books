# %% [markdown]
# ### Decision Trees
#
# Decision trees are versatile machine learning algorithm that tcan perform both classificaiton and regression task, andn even the multioutput tasks. They are fundamental component of random forest, which are one of the most powerful machine learning algorithms avaialble today.
#
# __Training and Visualizing a decision tree__

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()

##Selecting petal length and width
X = iris.data[:,:2]
y = iris.target

# %%
tree_clf = DecisionTreeClassifier(max_depth = 2)
#max_depth is the size of the tree 
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from joblib import dump

dump(tree_clf, 'models/ch_06/tree_clf_iris.pkl')
# Out:
# ['models/ch_06/tree_clf_iris.pkl']

# %%
##Visualizing the tree using export_graphviz() method

from sklearn.tree import export_graphviz

export_graphviz(
tree_clf,
out_file = "visualizations/iris_tree.dot",
feature_names = iris.feature_names[2:],
class_names = iris.target_names,
rounded = True,
filled = True)

# %% [markdown]
# We can use the dot command-line tool to convert this .dot file into png/pdf.
#
# ```$ dot -Tpng iris_tree.dot -o iris_tree.png```
#
# Or use pydot

# %%
import os
os.system('dot -Tpng visualizations/iris_tree.dot -o visualizations/iris_tree.png')
# Out:
# 1

# %% [markdown]
# Checking the tree
#
# ![DT](visualizations/iris_tree.png)

# %% [markdown]
# ### Making Predictions
#
# When we are making a classification, we start at the root node and check the petal length, if it's smaller or greater than 5.45 cm. Then we move to the second node and compare the petal width and petal length again based on if we are on left or right side of the tree.
#
# The node's gini attribute measures its impurity: a node is pure when the gini = 0. If all the instances it applies to belong to that class.
#
# Formula for Gini impurity : $ G_i = 1 - \sum ^n _ {k=1} p_i k^2$
# where, $p_{i,k}$ is the ratio of the class k instance among the training instances in the $i^{th}$ node.
#
# One of the many qualities of Decision Trees is that they require very little data preparation. In fact, they don’t require feature scaling or centering at all. The nuber of children depend on the number of classification classes.

# %% [markdown]
# #### White box vs the Black box
#
# - _white box models_ : which are easy to intrepret, like decision trees
# - _black box models_ : like random forest, the are great predictors and can be calculated but hard to explain the the reason of prediction since they are mor complex.

# %% [markdown]
# ### Estimating Class Probabilties
#
# Instead of classifying into the classes, the DT can also output the probability of belonging to that class. Fot this, it traverses the tree to find the correct leaf node and then returns the ratio of training instance of class k in this node.

# %%
tree_clf.predict_proba([[5,1.5]])
# Out:
# array([[0.14285714, 0.71428571, 0.14285714]])

# %%
tree_clf.predict([[5,1.5]])
# Out:
# array([1])

# %% [markdown]
# ### CART Training Algorithm
#
# ```sklearn``` uses CART (classification and regression tree) algorithm to train decision trees (also called growing trees). The algorithm works by first splitting the training set into two subsets using a single feature k and a threshold $t_k$ by searching for a pair ($k,t_k$) that produces the purest subsets (wghtd by the size)

# %% [markdown]
# \begin{equation*} J(k, t_k) =  \frac {m_{left}} m G_{left} + \frac {m_{right}} m G_{right}\end{equation*}

# %% [markdown]
# where
# Gleft/right measures the impurity of the left/right subset,
# mleft/right is the number of instances in the left/right subset.
#
# After splitting the training set into two, it splits the subsets using same logic, then further down, recursively. It stops on reaching the maximum depth (defined by max_depth), or if it cannot find a split that reduces the impurity.
#
# Other hyperparamters for tuning are
# - min_samples_split
# - min_samples_leaf
# - min_weight_fraction_leaf
# - max_leaf_nodes
#
# CART algorithm is a greedy algorithm, it greedily searches for an optimum split at the top level and then repeats the process at each subsequent level. It doesn't check if the split will lead to lowest possible impurity at later stages. Hence the tree is good, but not always optimal. Finding an optimal tree is a NP-Complete problem it requires O(exp(m)) time making the problem intractable even for small training sets.

# %% [markdown]
# ### Computional Complexity
#
# Making predictions requires traversing the Decision Tree from the root to a leaf. Decision Trees generally are approximately balanced, so traversing the Decision Tree requires going through roughly O(log (m)) nodes. Since each node only requires checking the value of one feature, the overall prediction complexity is O(log (m)), independent of the number of features. So predictions are very fast, even when dealing with large training sets.
#
# Comparing all features on all samples at each node results in a training complexity of O(n × m log (m)). For small training sets (less than a few thousand instances), Scikit-Learn can speed up training by presorting the data (set presort=True), but doing that slows down training considerably for larger training sets

# %% [markdown]
# ### Gini Impurity or Entropy
#
# By default the DT use gini impurity for spliting the node, but we can set it to entropy usign the ```criterion``` hyperparameter to ```"entropy"```. The concept of entropy is derived from thermodynamics.
#
# $H_i = - \sum ^n _{k=1} p_{i,k} log_2 (p_{i,k})$
#
# Gini impurity or entropy do not make a big difference, they often lead to similar splits. Gini impurity is slightlty faster to compute, hence it's defualt. When they differ, gini impurity tends to isolate the most frequent class in its owen branch of tree, while entropy tends to produce slightly more balanced tree.

# %% [markdown]
# ### Regularization Hyperparameters
#
# Decision tree make very few asusmptions about the training data (contrary to the linear algorithms). If left unconstrained, the tree structure will adapt itself to the training data, fitting it very closely - most likely overfitting it. Such a model is called non paramteric model, not because it does not have any parameters (it often has lot) but because the number of paramters is not determined prior to training, so the model structure id free to stick close to the data. In contrast, a parateric model, like linear model, has fixed (predetermined) number of paramters, so its degree of freedom is limited, reducting the risk of overffiting (but increasing the risk of underfitting)
#
#
# To avoid overfitting the trianing data, you need to restrict the descision trees's freedom during the triaining. it's called regularization. Regularization paramters depend on the algorithm used, but generally we can at least restrict the maximum depth of the decision tree. Reducing the max_depth with contraint the model and reduce overfitting.
#
# Other algorithms work by first trianing the decision tree without restrictions and then pruning the unnecessary nodes. If a node has all unnecesary leafs based on gini impurity and other statistical test like chi-square test and p test, then the node is entirely removed. the pruning continues until all such nodes are removed.

# %% [markdown]
# ### Regression
#
# DT are capable of performing regression tasks. We can do it in ```sklearn``` using ```DecisionTreeRegressor```

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth = 2)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
dump(tree_reg, 'models/ch_06/tree_reg_iris.pkl')
# Out:
# ['models/ch_06/tree_reg_iris.pkl']

# %%
##Visualizing the tree using export_graphviz() method

from sklearn.tree import export_graphviz

export_graphviz(
tree_reg,
out_file = "visualizations/iris_tree_reg.dot",
rounded = True,
filled = True)

# %%
import os
os.system('dot -Tpng visualizations/iris_tree_reg.dot -o visualizations/iris_tree_reg.png')
# Out:
# 1

# %% [markdown]
# Checking the graph
#
# ![Graph](visualizations/iris_tree_reg.png)
#
#
# This model’s predictions are represented as a polynomial graph with each depth set. the predicted value for each region is always the average target value of the instances in that region. The algorithm splits each region in a way that makes most training instances as close as possible to that predicted value.
#
# The CART algorithm works mostly the same way as earlier, except that instead of trying to split the training set in a way that minimizes impurity, it now tries to split the training set in a way that minimizes the MSE.
#
# Just like for classification tasks, Decision Trees are prone to overfitting when dealing with regression tasks

# %% [markdown]
# ### Instability
#
# DT are versatile and powerful algorithms, but they do have some limitations. The divide the space in orthogonal patterns, making them sensitive to trainign set rotations. Putting limitations to generalization capactiy. This problem can be solved using the PCA (principle component analysis).
#
# Another issue with DT is that they are sensitive to small variations to the data. Random Forests can limit this instability by averaging predictions over many trees

# %% [markdown]
# ## Exercises
#
# __1. What is the approximate depth of a Decision Tree trained (without restrictions) on a training set with one million instances?__
#
# Considering a balanced binary tree for the questions, the depth of a binary tree containing m leaves is $log_2 (m)$. Here, m = 1 million. so  $log_2 (10^6) = 6*log_2 (10) = 6*3.32 = 19.9 $  This will be higher if we have an unbalanced tree.
#
# __2. Is a node’s Gini impurity generally lower or greater than its parent’s? Is it generally lower/greater, or always lower/greater?__
#
# As we move down a tree, it starts to refine the classes criteria, hence the purity of a class in lower nodes is expected to be high, which sets the gini impurity of the child node to be lower than the parent. However, this might not be the case always, the gini impurity can increase at a child node before decreasing for the next child node.
#
# __3. If a Decision Tree is overfitting the training set, is it a good idea to try decreasing max_depth?__
#
# Yes, since the DT is a non parametric model, it has a high degree of freedom which results in high likelihood of overfitting. To decrease the overfitting we can regularize the model by decreasing the max_depth, which limits its degree of freedom.
#
# __4. If a Decision Tree is underfitting the training set, is it a good idea to try scaling the input features?__
#
# Decision tree is indifferent to scaling of the input features. Hence, scaling the variables has no impact on underfitting or overfitting.
#
# __5. If it takes one hour to train a Decision Tree on a training set containing 1 million instances, roughly how much time will it take to train another Decision Tree on a training set containing 10 million instances?__
#
# The computational complexity for a DT is defined by $O(n * m log(m))$ where n is the number of features and m is the number of instances. Since we know   $O(n * m log(m))$ = 1hr here, changign m to 10m will be  $O(n * 10* m log(10*m))$ ~ 12 hrs.
#
# __6. If your training set contains 100,000 instances, will setting presort=True speed up training?__
#
# presort helps increase the trianing speed in small number of samples, with 100k samples, the presort will slow down the trianing due to large sorting task.

# %% [markdown]
# __7. Train and fine-tune a Decision Tree for the moons dataset by following these steps:__
#
# __a. Use make_moons(n_samples=10000, noise=0.4) to generate a moons dataset.__
#
# __b. Use train_test_split() to split the dataset into a training set and a test set.__
#
# __c. Use grid search with cross-validation (with the help of the GridSearchCV class) to find good hyperparameter values for a DecisionTreeClassifier. Hint: try various values for max_leaf_nodes.__
#
# __d. Train it on the full training set using these hyperparameters, and measure your model’s performance on the test set. You should get roughly 85% to 87% accuracy.__

# %%
from sklearn.datasets import make_moons

X,y = make_moons(n_samples=10000, noise=0.4)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train , y_test = train_test_split(X,y,test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

params = [{'max_leaf_nodes':[2,3,4,5,6,7]}]
tree_moon_clf = GridSearchCV(DecisionTreeClassifier(), param_grid = params, cv = 5,scoring='accuracy')

# %%
tree_moon_clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid=[{'max_leaf_nodes': [2, 3, 4, 5, 6, 7]}],
#              scoring='accuracy')

# %%
tree_moon_clf.best_params_
# Out:
# {'max_leaf_nodes': 4}

# %%
from joblib import dump

dump(tree_moon_clf,'models/ch_06/tree_moon_clf.pkl')
# Out:
# ['models/ch_06/tree_moon_clf.pkl']

# %%
y_pred = tree_moon_clf.predict(X_test)

# %%
##Calculating accuracy
sum(y_pred == y_test)/len(y_pred)
# Out:
# 0.854

# %% [markdown]
# __8. Grow a forest by following these steps:__
#
# __a. Continuing the previous exercise, generate 1,000 subsets of the training set, each containing 100 instances selected randomly. Hint: you can use Scikit-
# Learn’s ShuffleSplit class for this.__
#
# __b. Train one Decision Tree on each subset, using the best hyperparameter
# values found in the previous exercise. Evaluate these 1,000 Decision Trees
# on the test set. Since they were trained on smaller sets, these Decision Trees
# will likely perform worse than the first Decision Tree, achieving only about
# 80% accuracy.__
#
# __c. Now comes the magic. For each test set instance, generate the predictions
# of the 1,000 Decision Trees, and keep only the most frequent prediction
# (you can use SciPy’s mode() function for this). This approach gives you
# majority-vote predictions over the test set.__
#
# __d. Evaluate these predictions on the test set: you should obtain a slightly
# higher accuracy than your first model (about 0.5 to 1.5% higher). Congratulations, you have trained a Random Forest classifier!__

# %%
from sklearn.datasets import make_moons

X,y = make_moons(n_samples=10000, noise=0.4)

# %%
from sklearn.model_selection import ShuffleSplit

moons = ShuffleSplit(n_splits=1000, test_size=.25, random_state=42)

# %%
moons.get_n_splits(X)
# Out:
# 1000

# %%
for train_index, test_index in moons.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
# Out:
# TRAIN: [4901 4375 6698 ... 5390  860 7270] TEST: [6252 4684 1731 ... 7647 7161   73]
# TRAIN: [8272 8183 4794 ... 7523 5830 1741] TEST: [6366 9628 5916 ... 2645 4344  706]
# TRAIN: [4143 6934 5777 ... 4139 7944 2156] TEST: [8740 7755 1092 ...  474 9159 4707]
# TRAIN: [9794 3720 2103 ... 6485 6249 8591] TEST: [4449 1468 6973 ... 1075 8382    4]
# TRAIN: [1240 1334 9287 ... 6040 2088 1478] TEST: [8718 1765 3011 ... 4612 7133  610]
# TRAIN: [6946 6654 4725 ... 2689 3367 7095] TEST: [1035 1792 8328 ...  606 6180 7114]
# TRAIN: [8574 4552 5640 ... 1925   89 9213] TEST: [4378 8822 7307 ... 2285 2920 8659]
# TRAIN: [5566 3090 5193 ... 6727 7699 9391] TEST: [4833 7004 1205 ... 1598 6870  187]
# TRAIN: [6285 1303 9763 ... 2080 6112  403] TEST: [8924 2398 3630 ... 2145 8763 8512]
# TRAIN: [3978 4851 1299 ... 9296  713 8780] TEST: [6169 7142  928 ... 4064 4129 2037]
# TRAIN: [3715 9910 9796 ... 4878 6983 4554] TEST: [5891 7577 8085 ... 6271 6308 7185]
# TRAIN: [4761 5931 4318 ... 2902 8812 3664] TEST: [4427 5691 5963 ... 5729 4593 4962]
# TRAIN: [8017 7872 6269 ... 9357 7054 3970] TEST: [6567 7181 6532 ... 1237 7752 1981]
# TRAIN: [9005 6061  943 ... 6837 4994 8842] TEST: [9083 4063 2357 ... 2786 6552 1904]
# TRAIN: [6717 4190  543 ... 9444 4264 7185] TEST: [5705 8355 8132 ...  429 3977 9122]
# TRAIN: [8320 8908 2998 ... 5666 5232 2987] TEST: [7120  893 6121 ... 2042 1175 4888]
# TRAIN: [5396  556 8373 ... 1077 8125 7367] TEST: [9366 3551 1046 ... 5264 7260  336]
# TRAIN: [2015 6714 1796 ... 4412  324 1111] TEST: [7088 7978 3836 ... 1972  322 9352]
# TRAIN: [4411 5244 1253 ... 6692 1752 4001] TEST: [ 352 5898 3285 ... 4042 3843  477]
# TRAIN: [3364 3528 3898 ... 6250 3454  964] TEST: [7383 4283 4616 ... 1115 4553 6133]
# TRAIN: [6926 2681 7557 ... 7009 9580 3716] TEST: [3553 1517 6069 ... 6469 2869 4456]
# TRAIN: [3571 3691 4606 ... 9027 9799 6734] TEST: [7548 3038  274 ... 4628 1513 9491]
# TRAIN: [9850 5334 7846 ...   98 7356 6393] TEST: [7527 7405 9685 ... 1855 9446 9502]
# TRAIN: [9158 4551 3175 ... 6715 6029 1968] TEST: [3709 2448 3959 ... 4099 7006 5936]
# TRAIN: [6179 5008 1435 ... 3535 3644 6293] TEST: [8002 3200 9751 ... 7578 9040   73]
# TRAIN: [1663 9892 5352 ... 1531 3751 9270] TEST: [9626 3500 2653 ... 9329  442 8593]
# TRAIN: [2448 6564 2909 ... 2292 5066  901] TEST: [ 286 7687  868 ... 2145 5080 2147]
# TRAIN: [5299 6119 7035 ...  153 2179 5231] TEST: [3481 6299 3580 ...  308 7130 8226]
# TRAIN: [ 716 1491 1351 ... 9927 8948 5115] TEST: [4608 2436 9330 ... 7974  981 1288]
# TRAIN: [9035 5400 7270 ... 5322 7456 1719] TEST: [ 130 3733 9983 ... 4643 5868 4413]
# TRAIN: [4242 2044 5564 ... 7644 4640 9925] TEST: [5140 6407  866 ... 3107 1534 6502]
# TRAIN: [6363  100 9028 ... 7419 8281 4161] TEST: [1201 7343 9721 ... 9346 3464  346]
# TRAIN: [4215 6594 6947 ... 8960 2893 7600] TEST: [6062 9845 1321 ... 2348 8869  931]
# TRAIN: [4988 8777    1 ... 1081 1892 1075] TEST: [6578 3653 6241 ... 8286 5791 9517]
# TRAIN: [2440 4407 1430 ... 4744 6187 4276] TEST: [1593  558  797 ... 7720 4292 9522]
# TRAIN: [6931 7508 5718 ... 9750 7924 7838] TEST: [8229 8716 2205 ... 6363 6707  206]
# TRAIN: [8455 1668  790 ...  108 6952 9410] TEST: [ 850 6773 6754 ... 9072 8062 3516]
# TRAIN: [5603 3243 8855 ... 1042  796 9886] TEST: [4064   91 6181 ... 1134 9769 2930]
# TRAIN: [7181 2947 6744 ... 3291 4309 3317] TEST: [1469 8092  417 ... 6852 1984  402]
# TRAIN: [3051 2471 9587 ... 5471 7970 8627] TEST: [1690 5131 6201 ... 6159 2660  333]
# TRAIN: [7928 2226 2730 ... 7513 6637 8072] TEST: [ 120 7291 3623 ... 8372 8800 8408]
# TRAIN: [5552 1948 5741 ... 3838 6267  880] TEST: [1634 3562  227 ...  846 5638 3027]
# TRAIN: [6741 9925 6988 ... 2862 2006 1403] TEST: [ 874 8394 3207 ... 5380 1857 4785]
# TRAIN: [4707  167 4620 ...  792 1607 3940] TEST: [7375 5316  185 ... 5560  491 5146]
# TRAIN: [9712 9835 7026 ... 5306 3169 8617] TEST: [5381 5339 7519 ... 7299 7472 5327]
# TRAIN: [3370 3031 6835 ...  256 7011 9939] TEST: [ 301 7586 2005 ... 5125  737 3883]
# TRAIN: [6254 3487 5002 ... 7207 3129 8478] TEST: [2130 2111 8823 ... 4876 1947 4063]
# TRAIN: [9195 1957 2603 ... 7927 8868 1311] TEST: [3295 7594 3543 ... 4754 9145 7419]
# TRAIN: [4667 5902 9708 ... 9067 9171 2478] TEST: [8011 2610 7497 ... 5949 4794 4188]
# TRAIN: [3822 5264 7852 ... 5226 6932 4747] TEST: [9823 3078 2714 ... 8569 8281 4109]
# TRAIN: [6263 3692 1382 ... 8166 6145 4455] TEST: [7821 4784 1332 ... 4534 7004 8677]
# TRAIN: [1477  907 4067 ... 6478 4955 8209] TEST: [3920 8595 7849 ...   44 1260 3673]
# TRAIN: [4294 8850 8674 ... 7853  287 8073] TEST: [ 359 7802 6316 ... 9694 7334  830]
# TRAIN: [8580  749 2825 ...  257 2728 7434] TEST: [5687 2025 7949 ... 3390 7192 3109]
# TRAIN: [6383 7719 5869 ...  156 4852 5549] TEST: [4186 6715 6744 ...  462 2769 9777]
# TRAIN: [ 139 2060 5527 ... 6599 2739  467] TEST: [4931 5231 1303 ... 3137 4230 7353]
# TRAIN: [4163 8586 4455 ... 4322 1328 4392] TEST: [2587  645 6149 ... 9055 3454 6464]
# TRAIN: [6125 1441 4404 ... 8632 7038 4745] TEST: [8082 2487 6420 ... 3018 9557 2849]
# TRAIN: [8362 4275 6170 ... 8879 6254 9510] TEST: [ 319 3830 5076 ... 5000 2992 5504]
# TRAIN: [9164 2758 5991 ... 6272 3214 1164] TEST: [7906 7156 3420 ... 1226 8289 2170]
# TRAIN: [ 202 4305 6168 ...  378 4800 1989] TEST: [7357 2580 2908 ... 9141 9461 4940]
# TRAIN: [ 505 8727 7225 ... 7574 5639 8686] TEST: [4115 2531 5310 ... 9723 1315 5178]
# TRAIN: [ 464 3391 2259 ...  840 2808 4825] TEST: [4464 8449 6758 ...  649 3277 6846]
# TRAIN: [7049 5544 8367 ... 1588 7509 3597] TEST: [3294 2325 6557 ... 9732 3342 2575]
# TRAIN: [5907 1769 5163 ... 1189 7032 9372] TEST: [8402  761 9284 ... 6574 2329  633]
# TRAIN: [1904 1421 2051 ... 1736 4336  103] TEST: [8125 5173 9643 ... 5428 3139 5793]
# TRAIN: [8354  195 9546 ...  676 6231 8984] TEST: [2962 3525 1905 ... 8292 1744 4503]
# TRAIN: [5208 7479 1156 ... 5340 1289 8625] TEST: [5987 7483 2314 ...  953 1501 8293]
# TRAIN: [ 453 9653 9969 ... 3364 4274 6125] TEST: [3817 7431 9449 ... 1201 5757 8313]
# TRAIN: [9917 3256 1161 ... 8876 1694 8919] TEST: [6605 6873 2432 ... 9524 6454  934]
# TRAIN: [9930  856 9668 ... 1933 9925 7874] TEST: [4340 1236 2639 ...  539 8444 2911]
# TRAIN: [2181 4288 5002 ... 5459 1445 6299] TEST: [7477 9357 9142 ... 7949 8432 3935]
# TRAIN: [4761 2434 9255 ... 6739 9610 9247] TEST: [ 791 4341    2 ... 8508 4778 6753]
# TRAIN: [ 975 4034 4663 ... 1521  611 5004] TEST: [5702 2812 3279 ... 5151  190 5848]
# TRAIN: [7143 1042 2065 ... 1797 5985 8102] TEST: [7763 7582   68 ... 4013 4376 5308]
# TRAIN: [2473 9062 4841 ... 8679 5379 3011] TEST: [8105 5879  656 ... 9910 6629 8498]
# TRAIN: [2669 2054 7653 ... 7836 4292 1385] TEST: [5018 3389 3310 ... 1312 3296 4656]
# TRAIN: [6377 2104 7257 ... 7183 2303  587] TEST: [6642 6767 6106 ... 4822 6777 7885]
# TRAIN: [9818 7260 5844 ... 4207 7385 4046] TEST: [3029 9920  174 ... 6121 5368 6470]
# TRAIN: [7555 3135 6409 ... 3003 8941 9630] TEST: [6912 4903 2712 ... 9619 9114 6451]
# TRAIN: [9612 6824 3139 ... 2537 6925 7536] TEST: [ 391 7179 1695 ... 1102 1158 2431]
# TRAIN: [ 870 6656 7730 ... 5078 8473 4762] TEST: [9064 4925 9957 ... 3711 8646 2285]
# TRAIN: [1036 5044   90 ... 1713  231 9744] TEST: [4486 6622 2108 ... 5220 5554 5077]
# TRAIN: [5603 3780 6592 ... 2846 4711 8656] TEST: [2553 5016 3472 ... 7904 7037 6631]
# TRAIN: [9841 8152 4585 ... 9331 2389 2248] TEST: [2170 9322 3468 ... 3018 8644 2917]
# TRAIN: [3461 8254 6488 ... 5711 4022  787] TEST: [8795 3260 4848 ... 8044 1988 3474]
# TRAIN: [3401 8182 7086 ... 5247 1067  795] TEST: [ 758 9385 4637 ... 3742 5448 8676]
# TRAIN: [5114 2486 3554 ... 1928 5621 8248] TEST: [ 932 4635 3475 ... 4004 6864  178]
# TRAIN: [2173 2178 8143 ... 4699 9479 1687] TEST: [2305 8425 8405 ... 2202 2056  752]
# TRAIN: [6339 5412 5361 ... 5019 1409  461] TEST: [1182 7269 6632 ... 8783 1361 1291]
# TRAIN: [8684 2518 9935 ... 3050 4313 8686] TEST: [4752 2306 8610 ... 1601 2296 4296]
# TRAIN: [ 373  540 3342 ... 6833 2391 7982] TEST: [4404 5203 5271 ...  272 8464 7150]
# TRAIN: [6422 5317 4182 ... 3626 3834 3483] TEST: [5870 2883 7375 ... 8206 8559  391]
# TRAIN: [1693 4588 7737 ... 4951 2194 6453] TEST: [4958 7290 8840 ... 7456 9864 6536]
# TRAIN: [1614 4268 8410 ... 1172 2925 2347] TEST: [1316 9844 2895 ... 1674 1647 3559]
# TRAIN: [9849 7817 8774 ... 4861 2068 8520] TEST: [9535 8060 4017 ... 7550 3769 6235]
# TRAIN: [5784  860 5394 ... 9367 6454 6901] TEST: [ 961 5481 2830 ... 9642  707 1987]
# TRAIN: [3999 3232 5300 ...  312 4287 7438] TEST: [9323 4886 7551 ... 5007 9582 3399]
# TRAIN: [1413 1547 1296 ...   15 7286 7934] TEST: [3947 9880 4120 ... 3991 4404 5112]
# TRAIN: [ 452 9478 5520 ... 6854 5695 3985] TEST: [8150 6228 9264 ... 6190 1914 8073]
# TRAIN: [9280 4400  605 ... 2568 9545 5029] TEST: [3014 4757 6402 ... 5928 7448 5075]
# TRAIN: [6015 4711  438 ... 4786  355 7727] TEST: [ 897 9034 4830 ... 3131 1034 9030]
# TRAIN: [9459  554 4109 ... 9244 2601 5157] TEST: [2901 4278 3892 ... 8267 5678 9042]
# TRAIN: [4044 4657 8868 ... 3679 5441 4062] TEST: [5952 3647 7463 ... 9649 1658  195]
# TRAIN: [7654 7636 9971 ... 6608 1076 9299] TEST: [2815 9594 5154 ... 4536 9675 4052]
# TRAIN: [6655 1450 7773 ... 3224 4351 9482] TEST: [ 110 9590  529 ... 6948 6929 3364]
# TRAIN: [3822 9832 1449 ... 9171  742 3693] TEST: [ 246 9149 4635 ... 1755 6019 8716]
# TRAIN: [1556 3524 5827 ...  522 6369 8257] TEST: [3483 4557 4682 ... 7955 7817 6073]
# TRAIN: [5233   32 4224 ...  553 7285 1715] TEST: [4455 9876 6397 ... 9616 5414 5309]
# TRAIN: [8910 1098 5349 ... 4913 5818 2585] TEST: [7302 7356 4339 ... 4894 7234 6598]
# TRAIN: [4382 2039 6646 ... 1059  800  579] TEST: [1826 1830 2707 ... 3416 1084 2819]
# TRAIN: [7275  372 5830 ... 7029 2302  679] TEST: [1517  620 9361 ... 8219 7952 4181]
# TRAIN: [1374 3371 9847 ... 1212 9447 2872] TEST: [8063 1896 5205 ... 4864 7253 5830]
# TRAIN: [6342   58 9704 ... 1699 3515 7959] TEST: [3999 5303 8895 ... 7387 5796 2008]
# TRAIN: [8388 7197 2150 ...   27 1733 7758] TEST: [6187 5630  893 ...  800 2269 5279]
# TRAIN: [7652 4800  751 ... 3440 9392 2179] TEST: [ 247 9944 9155 ...   56 5581 2633]
# TRAIN: [3387  477  219 ... 8751 9587 9942] TEST: [1449 6622 6247 ... 3430  593 1781]
# TRAIN: [7884 9727 4266 ... 8254 3074 1399] TEST: [1115 4688 8881 ... 7086 5676 5232]
# TRAIN: [5729 7765 3858 ...  420 3315  757] TEST: [ 110 5383 5434 ... 6461 4295 7481]
# TRAIN: [3418 9904 1117 ... 1300 6114 8367] TEST: [ 606 7965 3829 ... 9734 5759 9799]
# TRAIN: [7952 9558 3415 ... 9138  212  961] TEST: [4182 2529 4201 ... 4794   19 4550]
# TRAIN: [3614 2054 1102 ... 3116 9952 9165] TEST: [2741 8649 9166 ... 9893 4897 3933]
# TRAIN: [3994 7832 7460 ... 3869 1576 6773] TEST: [1030 1673 1891 ... 2098 8136 2082]
# TRAIN: [8122  421 5268 ... 3500  834 5582] TEST: [8154  721 4505 ... 2796 4939 4301]
# TRAIN: [4303 3711  247 ... 2341 9627 2546] TEST: [2926 6928 6559 ... 4465  667 4134]
# TRAIN: [2930 9894 8227 ... 2804 5591  786] TEST: [1769 2905 8309 ... 5931 5642 7291]
# TRAIN: [1423  102 8217 ... 5427 1085 8872] TEST: [5783  416 8278 ... 4526 1610 8847]
# TRAIN: [ 448 7512 3974 ... 3777  596 3373] TEST: [ 915 2960 8065 ... 5615 4533 7138]
# TRAIN: [9355 7260  614 ... 5297 4671  397] TEST: [7694 2565 5092 ... 7665 4790 3122]
# TRAIN: [5088 6248 1674 ... 7038 7260  854] TEST: [3584 1843 3848 ... 2227 7459 4809]
# TRAIN: [6946  861 5877 ... 4523 6555  298] TEST: [8484 5501 6831 ...  209 2156 9976]
# TRAIN: [7026 4559 1095 ... 9092 4244 8825] TEST: [ 665 7307 2620 ... 1166 7507 8008]
# TRAIN: [9870 5558 1514 ... 6174  596 2738] TEST: [ 461 7669 8443 ... 7837  307 1835]
# TRAIN: [4944 8264 9677 ... 5478 3229 7250] TEST: [7521 7262 1676 ... 4193 6971 3487]
# TRAIN: [5228 2510 7795 ... 2449 7833  479] TEST: [8975 7115 8225 ... 9463 7403 5808]
# TRAIN: [7797 1133 6327 ... 9043 2800 5941] TEST: [6390 1492 1555 ... 7607 6000 5366]
# TRAIN: [7736 4591 4346 ... 6204 7265 8184] TEST: [2834 4134 7686 ... 9275 5628 4307]
# TRAIN: [2120 6010 2086 ... 1384  575 6558] TEST: [8458 7653  871 ... 6210 1366 9040]
# TRAIN: [8683 8907 7394 ... 6573 4841  982] TEST: [3956 6089 7827 ... 7495  479 2780]
# TRAIN: [2144 7201 7660 ... 1717 9067 7465] TEST: [6714 1902 5565 ... 1014 8287 1692]
# TRAIN: [8794 3313  661 ...  689 1990 9834] TEST: [ 344 4648 6382 ... 8187  633 1571]
# TRAIN: [2740 5112 4049 ... 6467 4470 5431] TEST: [9777  442 5556 ... 9635 1798 4513]
# TRAIN: [8416 7779 7361 ... 3917 7934 6738] TEST: [1815 9310 8193 ... 6984 3638 3316]
# TRAIN: [1947 6681  582 ... 6072 3973 7918] TEST: [1889 2325 3540 ... 8592 5740 7360]
# TRAIN: [8707 4262 2362 ... 4387 7632 9248] TEST: [2010 1795  705 ... 1786 8179 9525]
# TRAIN: [2505 4156 3602 ... 1461 1949 8625] TEST: [5284 1517 1782 ... 4833 9527 9840]
# TRAIN: [ 516  530 3736 ... 2695 3504 7089] TEST: [1696 3554 8006 ... 6545 1416 5645]
# TRAIN: [5755 2036 3030 ... 1300 4822 6070] TEST: [1604 9489 8334 ... 8545 1584 2597]
# TRAIN: [ 672 4306  233 ...  470 5195 4361] TEST: [6995 3413 3478 ... 8351 2157  286]
# TRAIN: [2155  412 1404 ... 4666 2843 6634] TEST: [2654 8469 7434 ... 7579 2870 2598]
# TRAIN: [5942 6917 1218 ... 7743 6612 4276] TEST: [7954 5951 1860 ... 9078 6085 6527]
# TRAIN: [3212 2337 4845 ... 3497  974 4343] TEST: [9908 9153 5165 ... 5212 7869 7466]
# TRAIN: [5663 2861 1573 ... 9895 7903 3956] TEST: [5617 9495 6771 ... 2340 5911 7212]
# TRAIN: [9983  301  157 ... 6378 9122 2571] TEST: [8281 2054  193 ... 8861 6156 2455]
# TRAIN: [4141 5176 7161 ... 1693 2539 4585] TEST: [6257 7527 3362 ... 1605 1836 8474]
# TRAIN: [3535 7504 8360 ...  169 2813 3652] TEST: [7741 2598 6493 ... 2780 5703 1591]
# TRAIN: [  56  567 3670 ... 2087 2402 1310] TEST: [9329 3241 9436 ... 8278 4343 2115]
# TRAIN: [2492 5322 2304 ... 2321  339 8956] TEST: [6899 9193 1394 ... 3808 4088 8162]
# TRAIN: [5811 5410 4821 ... 5989 4354 5653] TEST: [ 139  752 6960 ... 7354 9597 7091]
# TRAIN: [5597 7993 8581 ... 6223 4390  831] TEST: [6674 9158 4551 ... 8021 7622 4010]
# TRAIN: [4449 5461 9122 ... 6693 8686 3611] TEST: [ 382 3121 6533 ... 4583 3360 5929]
# TRAIN: [1511 3297 3279 ... 7435 7866 8033] TEST: [5782 2016 5255 ... 8143 5968 3915]
# TRAIN: [4196 7654 9039 ... 1749 6977 2388] TEST: [3386 4561 9715 ... 2835 4294  704]
# TRAIN: [4692 2085 9215 ... 5087 7617 5254] TEST: [3537 1460 2560 ... 7247  773 1491]
# TRAIN: [2412 2692 8956 ... 8942 6615 6176] TEST: [4030 6178 9947 ... 2192 4376 7196]
# TRAIN: [6416 6789 6807 ... 3895 8814 4898] TEST: [6317 1641 3683 ... 3446 5566 2105]
# TRAIN: [2107 7641 8665 ...  109 8389 1210] TEST: [3014 8786 9687 ... 3200 5725 5632]
# TRAIN: [8737 2744 5678 ... 7715 2815 8191] TEST: [4450 7159 8063 ... 2945 5645 9789]
# TRAIN: [5424 5487 6827 ... 3402  388 4635] TEST: [8687 1500 1842 ... 3594 4022 6958]
# TRAIN: [6059 1002 9575 ... 9589 7210 6663] TEST: [ 966 8959 2733 ... 9767 3223 5936]
# TRAIN: [3201 7575 7542 ... 8119 8362 5103] TEST: [2475 2277 8699 ... 3007 5392 1682]
# TRAIN: [5889 3536 2086 ... 4369 2516 2904] TEST: [7662 2791    9 ... 7417 3703 5211]
# TRAIN: [9027  278 1239 ... 7269 3028 7136] TEST: [ 186 6834 3669 ... 4632 6727 6724]
# TRAIN: [6132 8613 9860 ... 8791 2452 3949] TEST: [8251 7594 7079 ...  905 1256 1538]
# TRAIN: [4976 8099 5520 ... 3782 7202 1559] TEST: [5460 5392 1156 ... 5428 4223 4283]
# TRAIN: [  58 4410 4171 ... 2344 5843 5331] TEST: [6172 6894 3734 ... 8927 5717 9374]
# TRAIN: [6266 6806 1112 ... 6631 3356   39] TEST: [2468 3294  774 ... 7015  332 2051]
# TRAIN: [3283 8877 6471 ... 9407 4827 9374] TEST: [2186 2356 5098 ... 6763 1643 9870]
# TRAIN: [6683 2612 9110 ... 6399 2304 8999] TEST: [4745 2438 6431 ... 8947  483 9996]
# TRAIN: [1047 2590 8960 ... 3272 7552  554] TEST: [9318 1681 7078 ... 8323 4865 4069]
# TRAIN: [5181 8879  280 ... 4994  641 2455] TEST: [1718 5457  580 ... 1409 1472 9666]
# TRAIN: [9505 1771 7145 ... 8040 6647 4041] TEST: [3354 5580 3894 ... 4216 2224 8063]
# TRAIN: [2375 8901 9921 ...  372 1922 8330] TEST: [6414 7806 9480 ... 2716 7801 2110]
# TRAIN: [4020 4790 3545 ... 6000 2978 2836] TEST: [8175  460 6731 ... 6397 1623 3231]
# TRAIN: [8387 7900 4861 ... 7143 8898  177] TEST: [3771 9720 1489 ... 5675 7180 3457]
# TRAIN: [4477  583 3567 ... 5102 5043 9643] TEST: [8164 1562 2740 ... 7940 3569 8619]
# TRAIN: [2880 9828 6970 ...  946 5357 7284] TEST: [1576 9832 1143 ... 2216  301 3590]
# TRAIN: [4786   11 4857 ... 5053 7676 9662] TEST: [3118 3494 4746 ... 5523 4183 5457]
# TRAIN: [2264 9909  690 ... 5288  607  453] TEST: [9706  233 8343 ... 6558    1   26]
# TRAIN: [4327 4340 9525 ... 4061  617 5409] TEST: [4604 5789 1666 ... 4291 7819 2797]
# TRAIN: [1380 2513 4297 ...  426 6439 8414] TEST: [ 890 8013 7226 ...  340 1140 9533]
# TRAIN: [5540 5467 1699 ... 8115 4614 9810] TEST: [  87 1535 8308 ... 6558  569 9703]
# TRAIN: [7413 4880 8504 ... 9136 8308 4383] TEST: [1293 6033 6956 ... 2181 4690 2308]
# TRAIN: [1974 2947 3515 ... 7765 7401 2589] TEST: [7555 2267  530 ... 1430 4698 7553]
# TRAIN: [2802  678 7712 ... 7349 8049 7499] TEST: [ 290 2767 8625 ... 5166 2346 4430]
# TRAIN: [ 674  955 4079 ... 5936 5276 9398] TEST: [8482 8386 1856 ... 6150 9208 6229]
# TRAIN: [4938 1063 4582 ... 9093 6627 4746] TEST: [2429  162 5299 ... 4847 8346 4281]
# TRAIN: [3942  885 5809 ... 3083  240 5661] TEST: [6150 1128 3273 ... 7892 9234 9760]
# TRAIN: [5593 6894 1749 ... 9698 1908 2958] TEST: [7422 2160 3331 ... 4088  203  169]
# TRAIN: [9903 7729 3071 ... 5982 4385 5689] TEST: [3566 2019 3576 ... 6615 1834  251]
# TRAIN: [7401 9425 6066 ... 1471 8762 4677] TEST: [7549 6943 9884 ... 4516 5548 2513]
# TRAIN: [8881 6322  476 ... 1554  352 4965] TEST: [4142 7660 5690 ... 7270 8309 5641]
# TRAIN: [5826 2277 5727 ...  825 6495 1213] TEST: [1479 6250 2848 ... 9055 8154 1070]
# TRAIN: [7663 8878 3447 ... 8521 7515 7969] TEST: [2116 1835 6855 ... 5212 4027  268]
# TRAIN: [3705 9848 8747 ... 8948 1530 2958] TEST: [9962 1277 4700 ... 1840 3855  538]
# TRAIN: [9211 5204 8485 ... 1106 4394 8422] TEST: [8383 5468 1327 ... 8173 9865 5619]
# TRAIN: [6714 8669  965 ... 6355 8251 4018] TEST: [ 171 3025  415 ... 6328  595 2838]
# TRAIN: [7025  918 4189 ... 7766 8983 5159] TEST: [ 940 5225 9195 ...  965 1443 7007]
# TRAIN: [1138 6192 8381 ... 7447 2828 4280] TEST: [5722 4154 8683 ... 4714 7588 7356]
# TRAIN: [1614 3402 8316 ... 8218 3039 5707] TEST: [8834  995 1130 ... 5448 4023 8270]
# TRAIN: [5312 6839 2685 ... 8172  323 1661] TEST: [3505 1603 4981 ... 6231 2640 5667]
# TRAIN: [6653  932 8105 ... 4687 8914  973] TEST: [8820 4667 8083 ... 7554  459 5465]
# TRAIN: [7188   76 6280 ... 5334 1804 4097] TEST: [3644 1890 8997 ... 8028  690  731]
# TRAIN: [3818 2262 4050 ... 8056 8796 2841] TEST: [3076 7870  108 ... 5581 2226 5130]
# TRAIN: [1159 7731 3047 ... 1899 8352  404] TEST: [7047 2254 1216 ... 1085 1961  934]
# TRAIN: [5126 2895 2979 ... 7305 4281  823] TEST: [2903 6853 6412 ... 8236 3759 8785]
# TRAIN: [6088 8115 8565 ...  743 2675 7198] TEST: [2653 2221  596 ... 4893 7954 3498]
# TRAIN: [8268 8191 6557 ... 4090 1261 7786] TEST: [ 400 6697 5943 ...  808 6086 1376]
# TRAIN: [1877 1779 4535 ... 4508 9193 1470] TEST: [9858  215  189 ... 7560 7638  590]
# TRAIN: [ 655 5467 4138 ... 7258 7828 5120] TEST: [2047 6603 4312 ... 8729 7381 9083]
# TRAIN: [9970 2165 1846 ... 7246 5137 1338] TEST: [2137 1109 7647 ... 6236  674 4052]
# TRAIN: [5239 3121 6591 ...  222 1389 2673] TEST: [4934 6518 3821 ... 2958 8444 9913]
# TRAIN: [5202  475 4446 ... 5973  493  310] TEST: [1678 1865  604 ... 7498 8337 4870]
# TRAIN: [7725 3065 5540 ... 8325 6717 4123] TEST: [7824 9951 5729 ... 4246 4915 2217]
# TRAIN: [3537 1554 4793 ... 7712 6391  663] TEST: [9421 9810 8224 ... 1241 8672 4405]
# TRAIN: [4979 8496 7780 ... 4564 4259 5259] TEST: [9668 5800 7723 ...  819 9818 1149]
# TRAIN: [9526 9141 3285 ... 3467 3380 3979] TEST: [3608 3251 5261 ... 6497 4869   30]
# TRAIN: [5451 9421 3939 ... 4339 7880 3011] TEST: [5919 8164 1753 ... 2688 2566 1627]
# TRAIN: [2876 6644 8322 ... 4948 3028 3795] TEST: [5952 9513 5801 ... 1874  132 2288]
# TRAIN: [9206 1517 2012 ... 2011 9517  496] TEST: [2704 9241 2128 ... 9429 5983 5079]
# TRAIN: [5893  131 6356 ... 6500 2760 1858] TEST: [ 370 4783 7828 ... 8240 2137  628]
# TRAIN: [4628 9153 2315 ... 9828 7487  826] TEST: [ 318 5590  380 ... 7755 2612 2890]
# TRAIN: [7589 7689 5258 ... 7059 8382 9766] TEST: [ 378 5616 7329 ... 2577 5918 5071]
# TRAIN: [9600 4568 5297 ...  300 8103 8789] TEST: [7170 7479 3764 ... 6709 9048 5896]
# TRAIN: [3470 4004 1649 ... 1327 3723 9060] TEST: [5934 3205 6559 ...  245 3569 1301]
# TRAIN: [1133 8958 8400 ...  873 7770 4809] TEST: [8438 7343 8716 ... 5191 9684 8897]
# TRAIN: [6815 6287 7297 ... 9408  232 5563] TEST: [9340  803 6174 ... 5450 5089 7809]
# TRAIN: [9461 2419 3096 ... 1737 6249 5455] TEST: [8349 7979 3041 ... 4882 5330 8754]
# TRAIN: [2037 8754 2442 ...  936 1562 6533] TEST: [9899 5083 8804 ... 2002 3649 5452]
# TRAIN: [9048 5376 4531 ... 3277 9961 1838] TEST: [1431 5580 4320 ... 5015 5348 9858]
# TRAIN: [1791 2745 1424 ... 5618 3728 1343] TEST: [8751 6982 4146 ... 7227    3 2317]
# TRAIN: [4072 2698 1145 ... 1300 4154 8864] TEST: [1213 8083 4450 ...   81 5873 6318]
# TRAIN: [5152 7626 5852 ... 9996 9990 6653] TEST: [7272 4553 7480 ... 1785 1542  793]
# TRAIN: [7664 5517 4924 ... 1576 7502 8649] TEST: [ 572 6877 6534 ... 4487 1460 9809]
# TRAIN: [3266 4865 5891 ... 9269 5907 4068] TEST: [5048 8672 2621 ... 3434 8581 7546]
# TRAIN: [4737  285 9559 ...  180 2264 6258] TEST: [9853  716 2744 ... 3692 9663 1756]
# TRAIN: [8135 7098 3905 ... 3757 8607 9501] TEST: [2000 7366 8909 ... 7762 9290 3018]
# TRAIN: [2231 5020  892 ... 3003 5019 8463] TEST: [5805 2664  657 ... 2277 1245 6593]
# TRAIN: [1885 2543 6125 ... 6070 1348 3198] TEST: [3478  812  342 ... 7556 6362 3407]
# TRAIN: [1969 5335 3372 ... 5499 2932 8476] TEST: [1690 3054 3920 ... 6768 9955 4770]
# TRAIN: [3147 7290 2626 ... 6928 8981 9184] TEST: [8723 4019  726 ... 6594 5105 9515]
# TRAIN: [2910 3173 4159 ... 1897 2294 7280] TEST: [4284 6035 6471 ... 9404 3029 3345]
# TRAIN: [3266 3640  175 ... 1988 2396 9804] TEST: [4796 7168  344 ... 7530 7226 5507]
# TRAIN: [1056 5466 4307 ... 1002 2721  440] TEST: [6687 6811 2166 ...  613 8342 5554]
# TRAIN: [ 282 6880 1496 ... 8798 5238 1628] TEST: [9820 2216 7818 ... 1539 2727 2520]
# TRAIN: [2203 8068 1527 ... 1783 1499 6944] TEST: [9628 9424 9572 ... 8620 8409 5658]
# TRAIN: [5674 1746 7946 ... 3322 7630 2075] TEST: [6448 9283 3480 ... 8940 2882 3588]
# TRAIN: [9033 2169 1320 ... 8694 2702 6428] TEST: [9776 6981 6217 ... 4302  540 8449]
# TRAIN: [4993 4331 3459 ... 5662 1765 1255] TEST: [4600 7214 9196 ...  225 5494 6073]
# TRAIN: [4073 5220 1969 ... 3035 2266 5545] TEST: [5837 2538 9914 ... 4539 7232 4769]
# TRAIN: [7860 8449 3205 ... 2220  341 4839] TEST: [8922 5599 8299 ... 3700 1420 3079]
# TRAIN: [8664  111 1152 ... 5911 7628 9708] TEST: [3504 4278 3691 ... 3282 3897 9373]
# TRAIN: [9336 1090 9369 ... 7338 2027 7076] TEST: [9807 5115 3086 ... 1617 7779 8488]
# TRAIN: [1227 1642 5502 ... 1240 6173 6488] TEST: [6848 5603 5003 ... 9518 2954  933]
# TRAIN: [4886 1318 3431 ... 3152 9818  519] TEST: [7705  287 9653 ... 8862 1907 5994]
# TRAIN: [9702 3505 4680 ... 6241  446 2401] TEST: [3988  942 7539 ... 8801 5315 3922]
# TRAIN: [7341 1851 7048 ... 5029 7641 6174] TEST: [6749 2718 2003 ... 7716 7118  943]
# TRAIN: [8182 3119 9968 ... 4786 4078 6432] TEST: [ 932 9062 4666 ... 6296 3667 3786]
# TRAIN: [4247 4967 5926 ... 9242 3986 3812] TEST: [2796 9664  726 ... 7648 1164 5797]
# TRAIN: [2599 8204 5610 ...  314 9601 5403] TEST: [8684 3559 5376 ... 8198 6758 6962]
# TRAIN: [3961 2559 4298 ... 1049 4001 4217] TEST: [7294 9668 9613 ...  135 5250 3714]
# TRAIN: [1370 7231 1349 ... 1119 9284 3915] TEST: [3133 7451 2625 ...  955 7785 6594]
# TRAIN: [4071 6567 3324 ... 4222 9008  675] TEST: [9032 8843 2507 ... 1580 6267 5595]
# TRAIN: [2548 7056   54 ... 6756 8337 3246] TEST: [2672 7065 2629 ... 8602  631  939]
# TRAIN: [4741 8533 6418 ... 4066 6892 5404] TEST: [ 384 3649 8445 ... 6731 1683 8783]
# TRAIN: [6472 5171 9424 ... 4523 1496 3430] TEST: [3251  844 8987 ... 1059 4485  151]
# TRAIN: [5445 2116  394 ...  979 4682 1985] TEST: [4742 5246 3054 ... 5443 9630 8118]
# TRAIN: [ 104 6298 4152 ...  199 2802 3656] TEST: [3347 2201 5971 ... 4482 7544 1109]
# TRAIN: [ 672 2672 7100 ... 5302  446 9935] TEST: [3967 2383 1552 ... 4700 2240 6356]
# TRAIN: [2393 1838 1350 ... 8805 9406 9204] TEST: [9591  323 9177 ... 3243 3645 4084]
# TRAIN: [4402 3277  581 ... 5698 9615 8039] TEST: [6250 1826 8337 ... 7553  697 3494]
# TRAIN: [1833 4353 9591 ... 6810 7286 7057] TEST: [1109 1631 7999 ... 7541 3036 3072]
# TRAIN: [6426 3596 4144 ...  279 6262 1433] TEST: [1722 8527 5635 ... 8375 8014 4759]
# TRAIN: [5533 2378 5987 ... 6341  739 1572] TEST: [5571 6413 3817 ...  337 1707 4277]
# TRAIN: [4373 9549 2423 ... 1755 6089 1375] TEST: [7580 6891 3675 ... 4542 2929 5389]
# TRAIN: [8043 7171 2424 ... 5134 9620 7830] TEST: [7970  394 8894 ... 8424 9854 8062]
# TRAIN: [8707  618 3416 ... 7113 9616 3725] TEST: [8031 1233 4219 ... 5959 9509 1691]
# TRAIN: [4330 7947 4298 ... 8715 4768 4261] TEST: [9135 7397 3116 ... 4721 8450 8749]
# TRAIN: [1168 5230 3384 ... 4567 5073 6341] TEST: [8764 5983 3516 ... 7840 7175 5570]
# TRAIN: [4953 6968 8028 ...  122 6294 1753] TEST: [ 868 4750 4353 ... 4215 7704 5383]
# TRAIN: [ 946 7206 7481 ... 4837 2847 7929] TEST: [3539 7128 3154 ... 3645 3484 9419]
# TRAIN: [2203 6035 1889 ... 3744 8761 3400] TEST: [6249 7641 2130 ... 5473 3215  920]
# TRAIN: [ 123 9426 8582 ... 9538 7639 8060] TEST: [4781 8688 7796 ...  417 4887 1670]
# TRAIN: [7802 5308  559 ... 2628 7443 6892] TEST: [4600  873 2851 ...  579  155 6314]
# TRAIN: [9899 5603 8608 ... 9313  105 9004] TEST: [4382 7556 9691 ... 4902 7722 1592]
# TRAIN: [5433 1801 9742 ... 6699  218 8028] TEST: [ 109 3020 9606 ... 4908 5818 5219]
# TRAIN: [8270  974 9368 ... 6275  698 9550] TEST: [6932 9804 1240 ... 4465 4890 5805]
# TRAIN: [4649 5277 1751 ... 6802 8116 1801] TEST: [3204 7784 7277 ...  183 6287 6347]
# TRAIN: [8435 6805 3874 ... 3236 3153  213] TEST: [2573 1361 2472 ... 1584 5331 6439]
# TRAIN: [9083 8698 2979 ... 7510 6887 5456] TEST: [4584 7473 3657 ...  430 9743 1971]
# TRAIN: [8644 1682 3342 ... 4882 6535 6923] TEST: [3096 7039 1324 ... 6753 4887 9938]
# TRAIN: [9363  599 8989 ... 1957 7355 5221] TEST: [7176 7225 9452 ... 4635 5513  214]
# TRAIN: [4170 8332 3817 ...  221 1005 3449] TEST: [8198 7442 6368 ... 1180 5052 7997]
# TRAIN: [9948 1675 6415 ... 1902 7922  579] TEST: [6033 1365 6827 ... 1523 2785 8471]
# TRAIN: [3167 1789 9496 ... 6559 9172 7038] TEST: [5510 2845 5141 ... 4895 3872 6192]
# TRAIN: [1984 5262 1904 ...    9 1421 4785] TEST: [5585 9509 1114 ... 8878 2823 2497]
# TRAIN: [7008 7500 6430 ... 5418 1815 1569] TEST: [4506  268 2614 ... 2610 9556 9236]
# TRAIN: [4862 4045 8092 ... 5911 1782 7463] TEST: [8917  855 5942 ... 1131 1512 3756]
# TRAIN: [2133  403 9690 ...  826 4195 8949] TEST: [3295  457 7419 ... 6162 1930 4305]
# TRAIN: [1681 4965 4938 ... 5878 7700  362] TEST: [5809 7797 8841 ... 2912 8913 2504]
# TRAIN: [4907 1225 7597 ... 1580 8097 3647] TEST: [8834 8673 1602 ... 9057  306 3555]
# TRAIN: [2999 7824 9959 ... 4204 4343 4517] TEST: [9210 3045 7915 ...  847  894 6119]
# TRAIN: [7244 4782 6228 ...  207 5013 8105] TEST: [5586 3766 2787 ...  473 4639 6283]
# TRAIN: [5674 6217 7071 ... 2935 2888 3652] TEST: [9656 2099 5776 ... 1650 2077 9511]
# TRAIN: [8956 7141 9300 ... 8583 2640 8263] TEST: [9499 3034 9599 ... 4969 8977 2062]
# TRAIN: [7112 5039 6983 ... 9668 7564 7016] TEST: [8915 9538 6977 ...  638 6042 2039]
# TRAIN: [7894 6179 8695 ... 7674 4379 7648] TEST: [2619 5898 2177 ... 8601 2780 8765]
# TRAIN: [7573 7230 7335 ... 3928  801 7691] TEST: [7450 2834 8918 ... 8311 3080 4858]
# TRAIN: [8877 9948 2955 ... 3883 9571 1531] TEST: [ 936 5843 3807 ... 2248 6731 4664]
# TRAIN: [4381 2077 6894 ... 4248 4339 1935] TEST: [1712 2129 5667 ... 9998 8957 8343]
# TRAIN: [9187 7747  301 ... 2784 4908 5572] TEST: [9472  206 1239 ... 6150 5268 2631]
# TRAIN: [9209 4337 8527 ... 4812 7120 7980] TEST: [1123 2360 9415 ... 9588 8652 7915]
# TRAIN: [4300 7415 1266 ... 4306 6530 2748] TEST: [4178 1276 9383 ... 2908 4111  400]
# TRAIN: [9933 2698 3587 ... 8722 3758 7732] TEST: [6796  981 9956 ... 9482 6053 9850]
# TRAIN: [1025 6901 7041 ... 6441 6881  531] TEST: [5810  981 5435 ... 8456 3647 8775]
# TRAIN: [6891 6219 6406 ... 8890 7967 6289] TEST: [1741 2573 3458 ... 6763 4501 1235]
# TRAIN: [2709 2074 8434 ... 9192 2630 3160] TEST: [1365 2521 8850 ...  236 7670 8781]
# TRAIN: [7853 8191 6824 ... 4876 2760 4367] TEST: [5688 5450 2438 ...  318 4765  612]
# TRAIN: [6557 7569 2264 ...  224 6521 3785] TEST: [3952 8609 6951 ... 4263 9628 5377]
# TRAIN: [8364 7409 1616 ... 3291 6508  134] TEST: [9677 1773 2883 ... 9433 5229 3710]
# TRAIN: [9044 4518 6248 ... 2578 9881 7525] TEST: [7212 7480 3782 ... 9375 1448 9041]
# TRAIN: [2091  286 5665 ...  237 4263 6369] TEST: [2015 6380 3116 ... 6410 7855  141]
# TRAIN: [  87 2868  205 ... 4179 4471  102] TEST: [1362 5919 1969 ... 2595 5736 6418]
# TRAIN: [9261 8180 9932 ... 5503 1300 8240] TEST: [8693 8943 5270 ... 9755 7152 6468]
# TRAIN: [6370 3552 5065 ... 3810 5448 2985] TEST: [6428 9491 3223 ... 5289 8803 9296]
# TRAIN: [6322 9815  760 ... 4039 2619 4557] TEST: [4395 5371 1979 ... 4484 3060 1413]
# TRAIN: [ 657 5437 5046 ... 9017 1958  268] TEST: [3080 8903 1116 ... 2640 3506 8468]
# TRAIN: [6095 8196 2267 ... 2852 2755 4710] TEST: [4066 9980   20 ... 3465 1080 1229]
# TRAIN: [9930 7169 7284 ... 4920 5649 9965] TEST: [3222 5844 7592 ... 4341 9200 9187]
# TRAIN: [3600  355 8319 ... 2137 1260 7110] TEST: [7220 5217 8871 ... 8592 2081 7115]
# TRAIN: [5542 5893 9490 ... 4036 4176 2327] TEST: [6900 9604 6714 ... 5269 4184 8220]
# TRAIN: [2908 3951 5629 ... 5975 6218 8092] TEST: [9276 3895 4555 ... 2572 9777 5070]
# TRAIN: [8306 7700 4164 ... 8451  483 4964] TEST: [2665 3913 7258 ... 8700 3873  436]
# TRAIN: [7629 9309 1269 ... 8269 9721  884] TEST: [5435 2580 7586 ... 9164 7154 9236]
# TRAIN: [4860 8274 7970 ... 1694 2258 2704] TEST: [8493 7318 5749 ... 5211 9156 9584]
# TRAIN: [7816 9584  880 ... 4222 9220 2520] TEST: [8682 1699 9692 ... 7697 9540  428]
# TRAIN: [5295 8137 3476 ... 7745  187 5660] TEST: [9019 6577 2336 ... 5808 4721 3877]
# TRAIN: [7807 6853 1061 ... 7706 3260 7445] TEST: [9265 8114 5124 ... 2608 7964  985]
# TRAIN: [ 180 7532 4015 ... 9579 8560  945] TEST: [ 298 7989 3065 ... 2257 1835 7923]
# TRAIN: [1693 3490 4883 ... 4967 4359 6048] TEST: [1590 7038  177 ... 2610 1995 4878]
# TRAIN: [9050 5828 5173 ... 5931 5613 2426] TEST: [5115 5566 8576 ... 9230 7772  587]
# TRAIN: [4989 2499 7609 ... 3167 7599 5824] TEST: [5094 6330 1611 ... 6237 2334 6236]
# TRAIN: [ 350 6125 7681 ... 7993 8710  509] TEST: [6952 6838 3034 ... 8507 2433 3996]
# TRAIN: [ 524 6100 4432 ... 4098 8087 2712] TEST: [6293 4166 9119 ...  590 8399 5108]
# TRAIN: [1644 9245 7348 ... 4445 5295 1571] TEST: [8015 1324   45 ... 8495 7619 7380]
# TRAIN: [9842 6990 2895 ...  389 4953 3612] TEST: [8803 4563 8374 ... 9261  477  949]
# TRAIN: [2665 1212 3246 ... 6314 3414 3747] TEST: [7711 3900 6260 ... 6844  638 1108]
# TRAIN: [  74 9791 4752 ... 8350 6098 5035] TEST: [6759 4429 8564 ... 9073 3360 8384]
# TRAIN: [ 613 9606 5853 ... 2273 5089 7586] TEST: [4304 2818 9221 ... 5179 5546 3540]
# TRAIN: [7528 5744 2981 ...  249 6161 6373] TEST: [8285 1874 9187 ... 2725 3337 4039]
# TRAIN: [5447 4488 2664 ... 2509 7275 8039] TEST: [8140  470 1568 ... 6023 1025 6863]
# TRAIN: [6822 4409 3402 ... 9735  218 4291] TEST: [8848 5973 8378 ... 7098 6334 6082]
# TRAIN: [9087 9286 1710 ... 2707 5173 5137] TEST: [1371 4608 5746 ... 2345 4842 1795]
# TRAIN: [6006 9964 1832 ... 6422 5008 5581] TEST: [4090 1960 8049 ...  372 5033 2705]
# TRAIN: [ 939   54  963 ...  827 6591 2099] TEST: [8697 1705 3672 ... 8963 8776 7609]
# TRAIN: [9958 6916 2650 ... 2056 6714 9394] TEST: [9606 9186  350 ... 8453  368 8716]
# TRAIN: [5081 4327 3895 ... 7090 1091 3314] TEST: [ 737 8332 8708 ... 1546 2483 5006]
# TRAIN: [7642 7661 2374 ... 6086 9679 7211] TEST: [9004 3015 2364 ... 9328 5277 5807]
# TRAIN: [6842  367 6363 ... 8327 7220 3932] TEST: [7931 3851 1913 ... 4686 8672 6685]
# TRAIN: [6749 4155 4027 ... 2428 6216   50] TEST: [8752 8325 8545 ... 6532 8582 5416]
# TRAIN: [1438 2764 2952 ... 8784 8699 9973] TEST: [3234 7027 8489 ... 5296 6152 1549]
# TRAIN: [7709 3312 2504 ... 6670 7193 9772] TEST: [ 705  648 5797 ... 6527 3797  242]
# TRAIN: [9504 2049 5253 ... 6972 2649 2440] TEST: [5186 6609 5722 ... 6896 9191 2218]
# TRAIN: [9699 9146 3642 ... 1742 7225 4890] TEST: [9526 8876 4351 ... 4486 7736 5013]
# TRAIN: [9571 3452 1935 ... 6544 9421 6710] TEST: [5742 8258  740 ... 6844 8766 6213]
# TRAIN: [5804 7137 5503 ... 9911 9973 7552] TEST: [4907 1798 8827 ... 8714 9344 1481]
# TRAIN: [2219 1364  294 ... 8045 6664  920] TEST: [ 672 2938 9805 ... 9246 4588  583]
# TRAIN: [9168 4849 5296 ... 3381 1813 8527] TEST: [8735 6924 4621 ... 6902 7374 1386]
# TRAIN: [6561 5163 3665 ... 7059 7301 4926] TEST: [2885 8193 4536 ... 5809 6322  325]
# TRAIN: [3866  230 7341 ... 3391 7873 2639] TEST: [4918 5220 9379 ... 8675 8608  709]
# TRAIN: [1045 5908 1253 ... 2488 1135 6193] TEST: [4687 3404 4545 ... 2494  654 1486]
# TRAIN: [2316 9848 3541 ...  900 4097 3569] TEST: [1522 7750 6722 ... 4745 2501 6969]
# TRAIN: [ 667 8260 6333 ... 1226 7254 7260] TEST: [3714 9214 8923 ... 6510 4702 4287]
# TRAIN: [5116 3518 7894 ... 3672  391 9726] TEST: [5251 1132 9266 ... 9311 4212 1796]
# TRAIN: [9659 7955 2173 ... 9337 9687 1481] TEST: [6194 7708 1862 ... 1908 1665 8931]
# TRAIN: [3794 8984 9340 ... 6204 4550 3560] TEST: [3282 5767 8839 ...  876 6114 1617]
# TRAIN: [5506 3430 2029 ... 2506 5878 5419] TEST: [7743 2410 1786 ... 8330 7243 8265]
# TRAIN: [3792 1814 1211 ... 8158 8655 9891] TEST: [9293 5271 8172 ... 5186 5114 2107]
# TRAIN: [5531 9237 1249 ... 7075  539 8693] TEST: [1494 5111 7368 ... 5441 4415 4106]
# TRAIN: [9827 3544 3243 ... 1174  585 3941] TEST: [9547 2911 8072 ... 7076 1997 3147]
# TRAIN: [2974 5189  289 ... 8738 2264 6915] TEST: [2699 5247 4259 ... 2010 7250 2412]
# TRAIN: [ 228 8620 4627 ... 3917 3307 3370] TEST: [1829 1333 5485 ... 4439 5785 4356]
# TRAIN: [1442  681 8835 ... 4880 2674 4572] TEST: [7154 9009 8371 ... 3058 1664 6206]
# TRAIN: [2932 8818  369 ... 5756 4622 4223] TEST: [6660   40 4614 ... 2428 2543 2167]
# TRAIN: [5230 4308 9729 ... 8049  809  188] TEST: [2008 6672 1047 ... 6477 9034 1903]
# TRAIN: [1720 1830 3100 ... 8044 7152 4887] TEST: [7143 7089 1346 ... 5930 1302 7389]
# TRAIN: [2757 9296 1131 ... 2487 7621 8191] TEST: [1753 3803 4495 ... 5710 9551 4179]
# TRAIN: [9174 7772 4131 ... 7180 2105 8393] TEST: [8120 8586  884 ... 4995  726 4978]
# TRAIN: [ 343 3753 3380 ... 1795 8719 8997] TEST: [8421 8909 3542 ... 7296 8812 3184]
# TRAIN: [8450 4530 6664 ... 4604  258 9432] TEST: [4196 8758 6366 ... 5350 5026 3419]
# TRAIN: [8422 9883 7915 ... 3644 7117 5630] TEST: [3170  501 3673 ... 2906 7906 6949]
# TRAIN: [6036 3316 4955 ... 5756 9240 7035] TEST: [1284 1640 7237 ... 5672 2625 3503]
# TRAIN: [5459 7072 1559 ... 9440 2942 3607] TEST: [8542 4484 6867 ...  229 8050  394]
# TRAIN: [1006 2892  158 ... 1718 1665 6286] TEST: [2562 6128 5885 ... 3676 1376 5652]
# TRAIN: [4768  983 1889 ... 8792 5662  908] TEST: [9191 9770 8432 ... 1570 4862  338]
# TRAIN: [3873 6912 2242 ... 1879 1037 9494] TEST: [5980 6396 7412 ... 7313 1486 4896]
# TRAIN: [6242 4226    6 ... 4013  744 5220] TEST: [1208 7264  825 ...  956 9305 9134]
# TRAIN: [7088 9015 9026 ... 9186 9120 2875] TEST: [ 410 5734 7792 ... 4052 1721 9898]
# TRAIN: [1503 3119 2626 ... 9433 7134 5952] TEST: [3024 4902 5277 ... 6041 4111 7752]
# TRAIN: [1783 8620  728 ... 2582 2285 6967] TEST: [6603 4477 6243 ...  121 4269 4735]
# TRAIN: [8826 1229 6873 ...  681 5905 9377] TEST: [1634 3021 2414 ... 3709 1276  396]
# TRAIN: [6774 6337 4679 ... 6190 7972 7827] TEST: [3582 7175 7683 ... 9432 4335 1040]
# TRAIN: [5048 9949 6986 ... 4425 4773 2389] TEST: [8914 9320  852 ... 2692   28 3681]
# TRAIN: [7403 5782 3319 ...  932 4363 3241] TEST: [6527  955 4865 ... 9237 6763 1763]
# TRAIN: [5270 5965 1958 ...  325 6099 6917] TEST: [4041 3132 2286 ...  684  659 2417]
# TRAIN: [8053 3078 5440 ... 9437 6326 3528] TEST: [5727 8051 4122 ...  849 7746 7088]
# TRAIN: [5364 7314 3482 ... 3436 8660 9454] TEST: [6393 8059 2164 ... 1288 9233 1214]
# TRAIN: [ 957 5897 3255 ... 7157 8396 1420] TEST: [7884 9484 2497 ... 7021 2927 3479]
# TRAIN: [3203 8754  374 ...  507 4498 8560] TEST: [5336 6991 3463 ... 9737 5702 7123]
# TRAIN: [3363  186 8854 ... 2092 7097  739] TEST: [7798 5702  964 ... 3010  277 2247]
# TRAIN: [8601 1441 3878 ... 8402 8286 8563] TEST: [4495 5484 7559 ... 1172 7348 3709]
# TRAIN: [ 411 1991 6286 ... 2430 4489 6952] TEST: [7286 3092 5098 ...  590 8560 7136]
# TRAIN: [3549  165 3605 ... 4414  951 3793] TEST: [1152 8610  975 ... 1133 5818 3857]
# TRAIN: [9372 8380 7237 ... 8713 7457 1865] TEST: [2592 9648 5508 ... 4990 2874 9069]
# TRAIN: [ 832 2195 7806 ... 4382 5611 2058] TEST: [6441 5782  784 ... 1353 1005 4252]
# TRAIN: [5366 5515 6730 ... 3168 7473 6936] TEST: [1553 8847 9137 ... 9477 1832  856]
# TRAIN: [8076  888 1758 ... 5694 4119 9057] TEST: [6238 3014 4095 ... 7993 3815 5617]
# TRAIN: [4672  572 2299 ... 2724 6464 5673] TEST: [4232 4739 8776 ... 1440 9388 6509]
# TRAIN: [1268 8688  436 ... 7997 2702 2822] TEST: [6022 5182 3340 ...  312 6016  635]
# TRAIN: [3368 7158 1267 ... 1462 4281 7990] TEST: [5179 4196 6754 ... 6823 5440 6938]
# TRAIN: [ 371 8023 2648 ... 3380 2287 1849] TEST: [4707 1910 2899 ...  776 1058  584]
# TRAIN: [9785 5696  250 ... 1615 1687 2272] TEST: [8023 2008 8118 ... 7900 5371 8067]
# TRAIN: [1942 9934 1372 ... 3391 5707 8578] TEST: [ 986  763  201 ... 1154 2302 8129]
# TRAIN: [2379 5561 8480 ... 1624 4227 5076] TEST: [4330 9962 2237 ...   34 1769 1865]
# TRAIN: [8729 3036 9053 ... 6380 8295 3868] TEST: [1438 9937 5933 ...  330 1161 6699]
# TRAIN: [4073 5636 8495 ... 9501  110 5560] TEST: [9818 2656  689 ... 5575 8903 5060]
# TRAIN: [5429 5375 9280 ... 4651 2817 6308] TEST: [4615 6676 4170 ... 6120 1530 9693]
# TRAIN: [5238 4740 6736 ... 1667 5356 1703] TEST: [2908 3815 4246 ... 8980 6439 2656]
# TRAIN: [3976 1051 2496 ... 3125 6165 7107] TEST: [9134 7319 1583 ... 2364 8757 4025]
# TRAIN: [9415  569 2796 ... 3171 4124 9316] TEST: [  82 4139 8673 ... 7182 5193 8161]
# TRAIN: [9043 5838 5794 ... 9330 8471 9469] TEST: [6026 1633 8805 ... 5172 7399 8831]
# TRAIN: [8361 4904 7327 ... 4805 3695 5631] TEST: [7738 5785 3532 ... 1916 1370 8809]
# TRAIN: [6624 3317 2797 ... 8313 7442 9437] TEST: [7813 6008 4175 ... 4345 3794 1270]
# TRAIN: [1608 5005 5515 ... 8810 1523 8164] TEST: [9144 9574 2295 ... 4258 7189 3376]
# TRAIN: [6038 2511 1411 ... 6162 7308  345] TEST: [6331 4017 8667 ... 9820 8831 2419]
# TRAIN: [9481 6317 2804 ... 2855  822 6828] TEST: [3467 7351 4032 ... 5403 8984 3567]
# TRAIN: [8817 5714 3830 ... 2017 9711 5267] TEST: [6099 8302  832 ... 5248 1828 6644]
# TRAIN: [ 768 2352 5600 ... 7579 3156 2943] TEST: [5305 6289 2520 ... 3765  615 9778]
# TRAIN: [7154 4866 7973 ... 1697 6546 6123] TEST: [3813 5221 6409 ... 4755 3799 4537]
# TRAIN: [2768 2810 1275 ... 7557  994 6323] TEST: [2319 2790 9823 ... 1311 9059 9728]
# TRAIN: [7934 8949 6611 ... 3780 2555 6060] TEST: [6559 9007 9396 ... 5303 9757 5567]
# TRAIN: [5732   25 4784 ... 2482 4936 7519] TEST: [4487 5024 3661 ... 9502 1610   35]
# TRAIN: [1352 6241 7860 ... 5396 6713 4104] TEST: [7313 7373 7440 ... 8841 1317  696]
# TRAIN: [4340 7379 3482 ...  392 9024 2927] TEST: [5002 4254 5667 ... 8623  756 5098]
# TRAIN: [1246 7891 9662 ... 6412 4451 8061] TEST: [8951 5742 1816 ... 6687 6473 9902]
# TRAIN: [3777 8642 1120 ... 8132 4740 7127] TEST: [9574  980 8896 ... 5765 5338  491]
# TRAIN: [6953 3925 5911 ... 5173 5747 4864] TEST: [9796 2312 3944 ... 1692 9093 4892]
# TRAIN: [2247 3296 9127 ...  449 6699 7264] TEST: [5575 3552 1290 ... 5883 5531 5408]
# TRAIN: [9326 4228 2913 ...  217 5621 7198] TEST: [4914 8184 8305 ... 1360 6631 9962]
# TRAIN: [2491 7677 6914 ... 7311 8955  589] TEST: [4822 5711 8823 ... 8242  766 4465]
# TRAIN: [9691 7616 5370 ... 7608 6610 5050] TEST: [ 738 2016 1874 ... 6120 6313 2626]
# TRAIN: [7315 9772 7414 ... 6703 2656 8401] TEST: [8322 5806 8642 ... 3835 5498 9488]
# TRAIN: [1887 3961 4294 ... 5188  641 8752] TEST: [9535 2334 3673 ... 7146 2567 9377]
# TRAIN: [2905  962 9265 ... 6791 5705 8212] TEST: [7710 2441 8474 ... 7304 6709 9513]
# TRAIN: [4528 9971 9874 ... 9767 4247 2566] TEST: [2192 2501 5619 ... 4773 3806 3216]
# TRAIN: [6977 8151 7433 ... 3726 7763 5879] TEST: [6889 8626 9010 ... 6314 7572 6685]
# TRAIN: [1231 5175 5645 ... 4922 8043 5827] TEST: [6540 2890 4050 ... 2559 9389 6834]
# TRAIN: [5258 5525 4207 ... 5673 1563 9278] TEST: [ 463 5511 1114 ... 6784 3072 6134]
# TRAIN: [2493 1869 4557 ... 1268 6179 7537] TEST: [7601 5193  904 ... 1651 4261 2223]
# TRAIN: [4372 5398 2330 ... 1517 1514  646] TEST: [ 697 1093 1944 ... 8529  337 1746]
# TRAIN: [4144 6288 3407 ... 9344 9843 9865] TEST: [6953 3265 3420 ... 3746  400 7060]
# TRAIN: [7268 5770 2007 ... 1799 1018 3120] TEST: [8756  771 3622 ... 5887 8306 1043]
# TRAIN: [2484 5801 3478 ... 4125 8815 6925] TEST: [ 566 2871 5026 ... 8239 2850 1024]
# TRAIN: [3536 5300 6668 ... 8343 4907 7273] TEST: [5246 9302 5969 ... 1732 7935 4029]
# TRAIN: [8261 2781 6517 ... 1253 9595 5097] TEST: [2491 8563 9298 ... 5642 6358 4080]
# TRAIN: [8199 5714 7416 ... 1170  707 4592] TEST: [2270 2675 7633 ... 5273 2602 8993]
# TRAIN: [3285 1465 2490 ... 1356 5345 8085] TEST: [4432 4408 5082 ... 4321 4284 3340]
# TRAIN: [9689 2709 1751 ... 1781 5362 7716] TEST: [9066  302 1733 ...  529 1514 7612]
# TRAIN: [2080 7691 1049 ... 4687 7025 8702] TEST: [1033 1081 3163 ... 8015 9173 6722]
# TRAIN: [1712 4676 4269 ... 4639 7235 2639] TEST: [4628 2429 4428 ... 9717 2224 9425]
# TRAIN: [6275 3648 5005 ... 9442 2168 4248] TEST: [9821 2874 6596 ... 1399 7101 8441]
# TRAIN: [7349 7035 7302 ... 4142 2415 2416] TEST: [2196 2109 4921 ... 4320 9906 3209]
# TRAIN: [7150  286  358 ... 4827  823 7870] TEST: [2584 2971 1381 ... 1716  817 5538]
# TRAIN: [1723 9682 1111 ... 3276 4236 7279] TEST: [8548 6117 5249 ... 1479 8965 1813]
# TRAIN: [7441  914 6672 ... 1237 9460 4783] TEST: [6425 2894 4704 ... 9463 7260 5787]
# TRAIN: [3498 3240  283 ... 3626 5176 6106] TEST: [3677 8018 6506 ... 4855 8919 2766]
# TRAIN: [4289 8809 9481 ... 1794  849 5407] TEST: [9911  190 6342 ... 9964 1414 3093]
# TRAIN: [ 466 1937   75 ...  247 9920 3130] TEST: [7733 9544 1007 ... 3435 1527  800]
# TRAIN: [9628 3386 4248 ... 2735 1261  590] TEST: [4381 5703  198 ... 3803 7286 9649]
# TRAIN: [1968 3826 7022 ... 4383 7213 8543] TEST: [7746 9430 7143 ... 9290 2777 1231]
# TRAIN: [5101 9341 4831 ...   33 8865  723] TEST: [9901 5195 1431 ... 9692 3397 7847]
# TRAIN: [3905 2967 9854 ...  507 2340 8856] TEST: [8871  231  245 ... 9302 4797  607]
# TRAIN: [3179 3205 7989 ... 4904 4244 3011] TEST: [6537 1870 6161 ... 2763 9538  549]
# TRAIN: [2467 2173 2388 ... 1714 2397  517] TEST: [4545  366 3904 ... 1929 9830 9195]
# TRAIN: [5965 8331 7723 ... 4913 2439 8607] TEST: [4766 7009 7297 ... 7205 4230 4771]
# TRAIN: [6877 3591 8519 ... 5483 2272 9481] TEST: [9814 7124 3962 ... 1198 2981 2780]
# TRAIN: [5127 4513 6840 ... 4519 2299 9204] TEST: [3170 2681 5440 ... 4333 7935 7404]
# TRAIN: [1217 8273 6974 ... 7981 8922 7333] TEST: [1941  258 2549 ... 8579 9071 2169]
# TRAIN: [7723 8067 2149 ... 3104 4896  331] TEST: [2161 8787 9204 ... 6464 2911 2096]
# TRAIN: [9318 5358 4693 ... 6712 6375 9297] TEST: [6186 2461 3848 ...  405 4737 7729]
# TRAIN: [9218 5795 2862 ...  556 8113 1951] TEST: [4475 4857 2421 ... 7073 1024 2952]
# TRAIN: [4253 1994 8319 ... 6723 7229 6657] TEST: [9438 9801 6489 ... 7091 5361 8580]
# TRAIN: [5957 2191 6179 ... 7845 4401 5106] TEST: [7470 2280 7145 ... 5660 5344 3068]
# TRAIN: [4781 1631 9943 ... 4191 5075 4136] TEST: [1825 2405 6276 ... 3525 8658 1043]
# TRAIN: [2345 1195 7875 ... 1083   93 1746] TEST: [1396 8107 4088 ... 1639 6140  373]
# TRAIN: [3495 3024 8363 ...  821 1664 7964] TEST: [1503 6553 8659 ... 9301 4629 1211]
# TRAIN: [6931 6808 6159 ...  470 5925 2139] TEST: [4203 7169 3678 ... 7093 6930 2409]
# TRAIN: [  92 6498 5730 ... 5077 1508 1600] TEST: [9528 3627 9094 ... 8536 1382 2964]
# TRAIN: [5784 6767 5654 ... 2426 6449 3823] TEST: [5186 6912 4456 ... 7018 5006 8382]
# TRAIN: [8003 8873 2860 ... 7477 8105 6196] TEST: [9372 7782 5331 ... 9307 4322 7476]
# TRAIN: [2144 1446 1606 ... 1799 9131 6020] TEST: [3296 3775 5605 ... 9151 4747 6611]
# TRAIN: [1435 5237 5318 ... 7935 3206 5382] TEST: [3793 5838 1927 ... 7199 5769 9145]
# TRAIN: [7397 3989 8545 ... 1316  877 4033] TEST: [4262  128 7569 ... 7380 2787 7808]
# TRAIN: [4408 3691 9321 ...  756 1539 9721] TEST: [5150 6506 8310 ... 4805 1224  811]
# TRAIN: [3273 4247 4348 ...  335 8683 9779] TEST: [2622 6342 5255 ... 7371 5245 7465]
# TRAIN: [1407 1102 9933 ... 3456 8599 4057] TEST: [9248  705  653 ... 8654 9772 5180]
# TRAIN: [ 792  386 7067 ... 4476 7721  543] TEST: [5534 4589 5137 ... 5805 3782 6476]
# TRAIN: [1568 7654 6928 ... 9578  504 1840] TEST: [3251 9551 8291 ... 1666  212 8561]
# TRAIN: [3267 5735  335 ... 4934 9206 3008] TEST: [8131 3970 6527 ... 7451 2347 7719]
# TRAIN: [5634 6024 6712 ... 5295 4393 6577] TEST: [4752 8718 9764 ... 2172 2787 6009]
# TRAIN: [4136 3299 8958 ... 6395 3402 9142] TEST: [5541 4595  798 ... 4849 6723 4697]
# TRAIN: [8817  244  124 ... 4184 6146 3057] TEST: [4095 5345 8724 ... 9036 7216 2605]
# TRAIN: [6453 8812  952 ... 8205 7988 9421] TEST: [7050  543 9850 ...  195 8799 9366]
# TRAIN: [6864  761 3377 ... 5412  865 5228] TEST: [2393 7888 5404 ... 7199 5268 9861]
# TRAIN: [ 967 9112 4918 ...  246 4590 7904] TEST: [5018 3031 4869 ... 3201 4673 6432]
# TRAIN: [1088 2195 2305 ... 9361 3498 5254] TEST: [4662 8136 8187 ... 6880 4808 2617]
# TRAIN: [6095 2827 2915 ... 3339 5030 1194] TEST: [6637 1254 2364 ... 3138 5853 4266]
# TRAIN: [6653 8107 9660 ... 9531 2005 1484] TEST: [1236 6305 1259 ... 9676 6554 5446]
# TRAIN: [7609 3067 2477 ... 9762 1144 3545] TEST: [5248 1242 6770 ... 8425  882 1705]
# TRAIN: [7944 2797 5787 ... 8758  959 4467] TEST: [1420 9712 2118 ... 3282 9314 1150]
# TRAIN: [ 348 5872  153 ... 2652 6078 8922] TEST: [ 868 2399 1912 ... 1448 2584 6930]
# TRAIN: [3741 6714 6317 ... 4292 4222 5589] TEST: [2617 2053 5804 ...  790 3212 2547]
# TRAIN: [3168 2548 9425 ... 7421 4941 1859] TEST: [5806 5904 3612 ... 1837  169 4791]
# TRAIN: [4453 8502 6760 ... 8522 3717 5413] TEST: [4812 8631 5286 ... 6187 2844 8551]
# TRAIN: [6904 4621 1568 ...  641 8282 5864] TEST: [5131 3772 9979 ...  769 8402 2971]
# TRAIN: [3833 6572 4900 ... 8490 8630 1498] TEST: [7734 3571 9050 ... 2995 5633 9550]
# TRAIN: [7630 5390 6014 ... 8025 4595 9123] TEST: [6518 7108  524 ... 1492 4056  718]
# TRAIN: [2770 6721 2682 ... 9409 6442 3978] TEST: [6010 1168 1310 ... 7367 4653 7909]
# TRAIN: [7530 8530 4190 ... 2862 7124 4848] TEST: [2647 2314 8146 ...  615 8348 9524]
# TRAIN: [ 381  155 4699 ... 1664 9429 3389] TEST: [7826 1754  213 ... 3836 1772 6684]
# TRAIN: [8028 3493 2660 ... 4346 9491 1557] TEST: [1127 6975 6825 ... 3442 5460 2291]
# TRAIN: [8134 6224 7752 ...  556  799 2901] TEST: [7371 8068 4120 ... 2244 7810 9135]
# TRAIN: [6113   40 3977 ... 4605 2616 5989] TEST: [1200 8150 3954 ... 6067 5785 9309]
# TRAIN: [7672 2413  872 ... 5607 5465 5051] TEST: [8230 2895  988 ...  360 6108 7451]
# TRAIN: [4074 7397 2176 ... 9645 1359 8916] TEST: [8094 5436 2359 ... 7852 6337 5604]
# TRAIN: [7033 4582 1118 ... 6401 3025 5918] TEST: [9894 1150  334 ... 9855 8001  853]
# TRAIN: [8516 8390 4371 ... 3497 1102 9850] TEST: [2885 4294 3073 ...  878 5448 5203]
# TRAIN: [6243 4082 8964 ... 2877 9293 3672] TEST: [3566 8632 5597 ... 8873 2790 7159]
# TRAIN: [3110 2074  562 ... 1398 6292 5602] TEST: [2789 9794 1319 ... 1392 3142 1459]
# TRAIN: [5805 2300  745 ... 4023 4239 8591] TEST: [1491 3723 2720 ... 9741 7588 1767]
# TRAIN: [3167 3353 4022 ... 2303 1182 7186] TEST: [5052 7981 7677 ... 3376 5797 7531]
# TRAIN: [6316  567 4756 ... 2100 7665 9806] TEST: [8959  143 7123 ... 1048 3245 4136]
# TRAIN: [2771 7128 3576 ... 6745 2882 5729] TEST: [5489 2929 4586 ... 8083 7987 4331]
# TRAIN: [7828 6656  548 ... 1879 9617 3436] TEST: [9531 2018 7547 ... 1350 6765 5428]
# TRAIN: [2901 7165 6273 ... 5832 4894 7389] TEST: [9055 6465 2307 ... 7675 7310 2910]
# TRAIN: [8018  741 6810 ... 6485 2947 1429] TEST: [2911 3490  731 ... 1480 7793 4887]
# TRAIN: [6249 7630 8152 ...  129 2034 6466] TEST: [1561 8325 7081 ... 5090  882 3381]
# TRAIN: [1059 4049 6021 ... 3127 6058 3629] TEST: [3281 3673 7649 ... 9339 6386 8947]
# TRAIN: [1450 9948 9958 ... 7972 6149 4949] TEST: [8684 7559 2606 ...  799 2540 1161]
# TRAIN: [6288 4721 7165 ... 7512 1286 4908] TEST: [2787 4755 6499 ... 8029 3601 4300]
# TRAIN: [1614 6052 6863 ... 3957 2304 3730] TEST: [8886 5784 5569 ... 7232 9810 2491]
# TRAIN: [9010 8273 2509 ... 2478 9325 3422] TEST: [8420  614 1308 ... 7622 6575  663]
# TRAIN: [3416 1580 9307 ... 7518 7043 7535] TEST: [ 573 5378 8531 ...  454 5230 4075]
# TRAIN: [5350 9031 5287 ...   12 9514 8871] TEST: [3632 7135 4280 ... 6831 6733 5325]
# ...
# TRAIN: [5743 4001 5829 ... 3955 3330  693] TEST: [7277  552 3444 ... 9605 3000 1723]
# TRAIN: [1243 7344 3045 ... 5562 1056  813] TEST: [3645 6742 9708 ... 2345 5768  942]
# TRAIN: [7877 4693 5625 ... 1157 9997 7267] TEST: [ 493 6975 5575 ... 9864 7353 7284]
# TRAIN: [1396 2126 1179 ... 4517 4560 9858] TEST: [ 758 8140 4938 ... 5294 4269 2340]
# TRAIN: [1564 5340 5028 ... 6249  694 3510] TEST: [1635 9460 2231 ... 8364 4349 2204]
# TRAIN: [4096 5364 5437 ... 1094 2309  252] TEST: [7423 6042 7090 ... 9655 2458 4749]
# TRAIN: [ 389 9717  744 ... 3642 2506 7111] TEST: [4711 9029 3457 ...  325 3755 9127]
# TRAIN: [4569 5230 6660 ... 1858 8372  577] TEST: [9179 4285 5198 ... 7755 3016 5998]
# TRAIN: [1057 5760 7265 ... 6612 1698 1523] TEST: [4404 7030 8676 ... 9324 9350 2177]
# TRAIN: [1134 6905 2292 ... 9250 4065 9310] TEST: [1058 9705 7921 ... 7914 3009 7650]
# TRAIN: [6305 2688 6570 ... 8482 4657 3285] TEST: [2155 4672 5960 ... 1680 5646    2]
# TRAIN: [3248 2457 1166 ... 7865 4229 6992] TEST: [9053  107 5735 ... 9366 3902 8731]
# TRAIN: [4112  987 9801 ... 8646 2986 6847] TEST: [4931 3804 7861 ... 1888 3173 2599]
# TRAIN: [2694 8157 4683 ...  603 8268 6655] TEST: [9251 9398 7870 ... 5053 8578 5246]
# TRAIN: [3124 2439 7363 ... 5726 4185 6248] TEST: [8337 7860  653 ... 1523 5594   24]
# TRAIN: [8188 8947 3958 ... 3689 9880 9276] TEST: [8542 6163 1589 ... 7484 6392 7945]
# TRAIN: [5726 6535 2438 ... 3776 3431 1326] TEST: [8938  609 6557 ... 5384 9813 8752]
# TRAIN: [6312 3398 8880 ... 9488  287 7899] TEST: [9826 6047 5833 ...  260 4024 4044]
# TRAIN: [7079 7013  109 ... 9340 8742 7935] TEST: [9816 6123 3917 ... 2588 3952 8915]
# TRAIN: [3653 1269 3073 ... 1005 1734 5322] TEST: [3410 6707 8468 ... 9503 8883  898]
# TRAIN: [ 631 3617 5167 ... 1770 2003 1238] TEST: [3130 2898 6831 ... 6987 3370 6036]
# TRAIN: [ 159 3593 2034 ... 4935 8615 4150] TEST: [7067 1358 4029 ...  374  132 1864]
# TRAIN: [2317 6881 7988 ... 8739 8460 7889] TEST: [9971 8126 6680 ...  665 7668 3199]
# TRAIN: [5072 6824 5317 ... 6662 5199 8759] TEST: [9440 6197  498 ... 1856 2089 6452]
# TRAIN: [9000 9763 6717 ... 6360 5996 9026] TEST: [6492 9109  885 ...  878  822  164]
# TRAIN: [2653  887 2853 ... 1664 9880 5630] TEST: [ 317 7563 8551 ... 6295 9008 7552]
# TRAIN: [7071 9198 1361 ... 4005 4639  697] TEST: [1044 7518 2979 ... 2763 6413 6307]
# TRAIN: [4384 1844 5597 ...  532 1665 4489] TEST: [8177 8897  631 ... 9607 3676 3696]
# TRAIN: [ 981 9478 7917 ... 8348 5424 6950] TEST: [1671 9008 9023 ... 6262 4107 2730]
# TRAIN: [6467 3856 7932 ... 4609 6281 3265] TEST: [7786 9603 3828 ... 6598 8747 4283]
# TRAIN: [1374 5296 6806 ...  991 1891 8553] TEST: [5486 8480  989 ...  425 1578 2738]
# TRAIN: [1826 9721 7686 ... 6678 3609 7309] TEST: [1186 1259 9984 ... 9584 1232 9280]
# TRAIN: [3462  359 5701 ... 4095 5496 9217] TEST: [ 256  128 6767 ... 5679 2203 1898]
# TRAIN: [  30 4135 9888 ... 1672  858 9108] TEST: [1825 9851 7802 ... 7632 8659 8718]
# TRAIN: [7921 5753 6520 ... 9992 2775 4710] TEST: [9390 5428 4791 ... 8906 3274  179]
# TRAIN: [6786 3209 1716 ... 9871  951 5987] TEST: [1832 4195 7763 ... 1581 2391 3122]
# TRAIN: [ 528  548 1150 ... 4131 7781 4482] TEST: [3270 5392 5281 ... 3043 7546 9164]
# TRAIN: [3165 4115 2771 ...  244 4379 5654] TEST: [3366  109 2896 ...  455 1930 8954]
# TRAIN: [5125 4162 4281 ... 5724 5280 9738] TEST: [  79 8741 7713 ... 8181 2303 8855]
# TRAIN: [5333 8925 4335 ... 5813 5629 8566] TEST: [1258 7180  496 ... 9679 3308  375]
# TRAIN: [7661 9078 5393 ...  141 1953 8671] TEST: [2187 5839 3531 ... 4333 8485 1536]
# TRAIN: [ 891 4421 4657 ... 5018 9155 8909] TEST: [1569 9073 8476 ... 8055 6227 4731]
# TRAIN: [6136 3264 2169 ... 1312 7426  514] TEST: [4878  117 8092 ... 8867 2890 6357]
# TRAIN: [9120 8504 8749 ...  341 2897 9394] TEST: [ 670 7923 9174 ... 8129 2622 1565]
# TRAIN: [1475 1648 2222 ...  448 6061 7354] TEST: [6099 1244 5643 ... 2718 6713 5976]
# TRAIN: [5021 8664 8085 ...  204 6090 4192] TEST: [5790 8850 7268 ... 4173 6798  714]
# TRAIN: [5422 6530 2848 ... 3209 1443 9861] TEST: [7590 5589 2471 ... 2323 1560 4672]
# TRAIN: [8539 8421 3171 ... 7127 1436 1784] TEST: [4935 6413 4756 ... 8664 9750 4272]
# TRAIN: [4813 3374 8364 ... 5093  881 7953] TEST: [5469 6539 7189 ... 7562  407 6228]
# TRAIN: [3382  536 5660 ... 9732 9210 2411] TEST: [9226 3073 9806 ...  544 3898 9521]
# TRAIN: [6603  995 6533 ...   81 3772 2848] TEST: [3666 9040 5350 ... 1731  314 7105]
# TRAIN: [3123 9844 5197 ... 4896 5685 6182] TEST: [5316 6410 4162 ... 1350 9714 7180]
# TRAIN: [6396 8182  203 ... 5815 6496 2028] TEST: [6249  223 8562 ... 7294  882 2417]
# TRAIN: [2113 6362 4324 ... 6173 7879 2088] TEST: [1886 9144 4467 ...  767  504 8291]
# TRAIN: [8272 9429 3784 ... 1292 3475 1488] TEST: [7652 1975 6308 ... 7716 7921 4051]
# TRAIN: [7566 9679 1150 ... 5006 5183 5911] TEST: [2208 4223 6658 ... 7238 7002 4580]
# TRAIN: [ 345 8189 4939 ... 8260 5707 9326] TEST: [4057 9914 9535 ... 7903 4290  477]
# TRAIN: [6639 8481 5737 ... 4370 9230 6151] TEST: [5328 8401 3894 ... 1146 2128 6824]
# TRAIN: [4955 2207 6151 ... 6649 2590 2744] TEST: [6978 5206 5695 ... 8150 1211 6899]
# TRAIN: [9341 6900  388 ... 4631 6719  633] TEST: [1115 7373 2018 ... 1747 5326 6639]
# TRAIN: [6544 5550 5447 ... 2885 4329 8717] TEST: [2975 1935 3322 ... 8350 9395 7350]
# TRAIN: [9090 2551 8929 ... 7706 3781 2189] TEST: [2303  816 5120 ... 3529 1563 9654]
# TRAIN: [7005 1110 1373 ... 1051 6352 5468] TEST: [5163 8884 3005 ... 3023 9971  136]
# TRAIN: [7170 8619 5836 ... 2739 8124 4176] TEST: [9099 7255 2765 ... 5008 4254 8218]
# TRAIN: [5987  453 3105 ... 1150 4740 1224] TEST: [5359 8223 7245 ... 5298 1474  571]
# TRAIN: [ 212 2778 6217 ... 5018 5763 3656] TEST: [9348  310 5085 ... 3527 1444  278]
# TRAIN: [1652  700 6432 ... 7059 9897 8268] TEST: [3833 3171 4973 ... 6397 3138 3282]
# TRAIN: [4764 2669 9534 ... 3816 6520 9276] TEST: [7731 1308 4339 ... 1633  593 9535]
# TRAIN: [1352 4089 7901 ... 6790 1992 8949] TEST: [7478 3561 3776 ...  271 5060 1448]
# TRAIN: [ 453 1430 4267 ... 7144 4725 4395] TEST: [7952 1537 9005 ... 7123 2348  224]
# TRAIN: [5492  599  925 ... 8655 7724 7649] TEST: [6169 1428 9550 ... 6108 9030 5378]
# TRAIN: [ 978 6521 7204 ... 5229 1731 9965] TEST: [4620 6243 9963 ... 4170 9863 8788]
# TRAIN: [4570 7045 3383 ... 5690 2815 4111] TEST: [4406 9591 2654 ... 2834 4935 6274]
# TRAIN: [4727 2166 4381 ... 8984 9582 4854] TEST: [4630  104 8788 ... 8894 5934 6748]
# TRAIN: [7645 6971 8877 ... 1645  648 5217] TEST: [1804 5136 6540 ... 1597 8076 2737]
# TRAIN: [6135 4751 4410 ... 4434 2293 3880] TEST: [1225 5956 3666 ... 8085 1950 8292]
# TRAIN: [9183 9455 4752 ... 6163 5202 4094] TEST: [5066  234 8376 ... 8234 8497 2565]
# TRAIN: [2871 2322 9367 ... 4662 3849 8290] TEST: [8814 8437 3717 ... 3418   10 1060]
# TRAIN: [3586 9177 6506 ... 8819 4008 5212] TEST: [2620 1963 3926 ... 5842 6839 5940]
# TRAIN: [7840 6963  755 ... 5697   56 6717] TEST: [4293 6919 3884 ... 9839 9970 1996]
# TRAIN: [2667 8902 2260 ... 5527 2907 5863] TEST: [ 736 3138 7105 ... 2064 4837 1010]
# TRAIN: [7282 8059 1979 ... 6467 2414 1123] TEST: [7702 3606 7439 ... 8023 4532 3616]
# TRAIN: [6720 8385 8778 ... 7198 7758    6] TEST: [8424 5157 3267 ... 7824 1108  315]
# TRAIN: [2315 6639 3513 ...  935 2079 1856] TEST: [3473 9897 5911 ... 2063 3754 3940]
# TRAIN: [1198 3100 9600 ... 8330 1593 8177] TEST: [ 447 7638 6580 ...  985 2912 6935]
# TRAIN: [4052 1864  333 ... 4491 6141 1559] TEST: [1388 2601 2751 ... 2603 2655 4331]
# TRAIN: [2769 2295 3553 ... 6993 5701 4669] TEST: [1410 8450 1853 ... 2666 3039 1651]
# TRAIN: [5831 7190 6319 ... 3525 3053 3249] TEST: [3444  423 7916 ... 2129 9722 5088]
# TRAIN: [8717 9832 8098 ...  583  265 2787] TEST: [ 851   77 2625 ... 9768 9024 2906]
# TRAIN: [7014 3217 1924 ... 3197 6029 3852] TEST: [6898 6172 5540 ... 5681 6007  670]
# TRAIN: [2459 7861 3947 ... 8522 9045 3873] TEST: [ 129 5517 9837 ... 8348  872 4588]
# TRAIN: [7425 7763 4498 ... 8366 1075 7855] TEST: [7176 3252  157 ... 9805 6818 4806]
# TRAIN: [6833 7908 3408 ... 6405 5393 4844] TEST: [2952 8736 6790 ... 9558 4804 1092]
# TRAIN: [8129 4498 8875 ... 4980 4417 4135] TEST: [6463 2833  392 ... 6106 5988 1683]
# TRAIN: [3571 9355 6315 ... 9452 3694 6510] TEST: [2663 6354  779 ... 2100 1059 2469]
# TRAIN: [8340 6168 7300 ... 5499 9874 4014] TEST: [3311 1338 1260 ... 8949  288 6814]
# TRAIN: [9056 3119 2660 ... 9290 9223 6093] TEST: [8762 9202 3735 ... 3576 5515 8154]
# TRAIN: [5461 9343 4422 ... 3261 8856  405] TEST: [6277 9621 3487 ... 7691 6873 5463]
# TRAIN: [7221 5142 4503 ... 5810 7155  370] TEST: [1501 2940  176 ... 3489 1823 8193]
# TRAIN: [2154 3520  548 ...  104 5127 1555] TEST: [8162 9628 6313 ... 4812 3086 5347]
# TRAIN: [6250 4155 7250 ... 8372  839 7654] TEST: [4456 3826 4881 ... 8796 4560 6402]
# TRAIN: [2490 7051 3977 ... 1301 1221 8935] TEST: [ 111 9607 9811 ... 6392 7101 7451]
# TRAIN: [4620  890 6498 ... 3619 1539 6080] TEST: [ 734 9122 9503 ... 1158 6148 8628]
# TRAIN: [9489 7616 3925 ... 8473 8891 9828] TEST: [ 958 8814 2070 ... 3697 1064 8086]
# TRAIN: [9437 8147 9860 ... 1227 6050 8543] TEST: [3738 3271  153 ... 4814 6385 9688]
# TRAIN: [ 131 6976 6831 ...  763 8746 5490] TEST: [6665 5209 6881 ... 7066 9673 8025]
# TRAIN: [5363 5527 9148 ... 3691  963 2007] TEST: [8267 5917 5627 ... 1132 7358 5188]
# TRAIN: [3430  279  679 ... 4644 7320  562] TEST: [7060 7878 5400 ... 6920 7513 7256]
# TRAIN: [9678 2505 2770 ... 9377 6775 2695] TEST: [2476 7155 4455 ... 1961 7325 9888]
# TRAIN: [4483 4527 6486 ... 9660 4252 3136] TEST: [1339 7157 5302 ... 5023 5590 5185]
# TRAIN: [3902 9913  595 ... 9733 7305 3015] TEST: [7760  611 4187 ... 8028 6247 7332]
# TRAIN: [7711 2341 1638 ... 1969 6534 1791] TEST: [2200 8406 7397 ... 9950 8720 6587]
# TRAIN: [ 926 8110 1350 ... 6822 1972 3683] TEST: [9527 1636 7666 ... 9323 9892 2757]
# TRAIN: [ 930 5560  297 ... 4399 4648 7962] TEST: [5084 5764 7590 ... 2026 3224 9185]
# TRAIN: [1040 5981 8330 ... 6287 6922 8270] TEST: [4749 6410 2674 ... 7727 9800 5023]
# TRAIN: [1084 4659 1724 ... 5175 2638 2965] TEST: [4261 2822 9854 ... 4927 9949 2120]
# TRAIN: [5732 6366 1325 ...  289 5561 4665] TEST: [8207   63 4727 ... 1051 1985  320]
# TRAIN: [9038 1098 9378 ...  673 4726 6832] TEST: [2276 6468 5101 ... 2580 6738 9862]
# TRAIN: [1602 4651 1554 ... 1699   73 7614] TEST: [8195 8048 3108 ... 8054 5470 6097]
# TRAIN: [9565 9126 5789 ... 9771 5613 7196] TEST: [7523 3164 2097 ...  954 4463 5980]
# TRAIN: [ 451 3031 8572 ... 3696  301 7834] TEST: [3058 9151 8410 ... 8135 2843 2571]
# TRAIN: [1263 4311 7910 ... 4298  724 9219] TEST: [2987 1555 4837 ... 1960 1085 7921]
# TRAIN: [4926 4903 9602 ... 1610  383 1813] TEST: [3523 3460 3338 ... 8878  310 4414]
# TRAIN: [4923 5874 3986 ... 2549 3937 4615] TEST: [ 288 8330 7753 ... 8901 3714 6767]
# TRAIN: [8989  976 2276 ... 2545 6241   18] TEST: [1664 7252 4202 ... 8256 5551 8185]
# TRAIN: [4587 2426  260 ... 4507 5068 4554] TEST: [3347 8626 8060 ... 1877 1331 7650]
# TRAIN: [3164 5907 8309 ... 3478 3043 5938] TEST: [1162 8294    4 ... 5703 4247 3786]
# TRAIN: [3290  113  600 ... 1410 2262 7482] TEST: [1148 5888 2845 ... 5582  415 7770]
# TRAIN: [5746 7953 3642 ... 8175  138   79] TEST: [8581 2746 4059 ... 2548 8777 1918]
# TRAIN: [ 612 2749  634 ... 2093 6147  877] TEST: [6908 9886  640 ... 1503 9022 9222]
# TRAIN: [1333 7889 5264 ... 2872 2150 8467] TEST: [7576 9738 4780 ... 2495 7004 8816]
# TRAIN: [7435    8 3147 ... 4939  863 7496] TEST: [3989 3630 9073 ... 9281 9271 4505]
# TRAIN: [3657 4008 5855 ... 3647 9469  197] TEST: [9966 7146 2483 ... 2657 7318 2811]
# TRAIN: [1130 7480 8477 ... 8143 9971  578] TEST: [6318 3080  757 ... 4566 6768 9282]
# TRAIN: [2251 7945 7664 ... 2981 3048 7032] TEST: [3860  821 7928 ... 8564  753 3206]
# TRAIN: [ 454 4240 7056 ... 2427 9346 4726] TEST: [4868 3232 2542 ... 6712 1016 6552]
# TRAIN: [2490 1356 2980 ... 7047 1820 8491] TEST: [9544 2411 9118 ... 9559 8906 8410]
# TRAIN: [7657 8219 3619 ... 2274 3930 2498] TEST: [9086 4945 1582 ... 6892 9574 3680]
# TRAIN: [2560  240 5362 ... 9352 4839 6516] TEST: [3916 6888 8770 ... 8034 3011 5723]
# TRAIN: [6794 9116 2113 ... 9849 3661 4183] TEST: [5180 9697 3497 ... 5786 4513 5106]
# TRAIN: [9746 5207 2479 ... 1208 9675 1578] TEST: [9992 1370 1590 ... 8774 2979  902]
# TRAIN: [5977 4141  293 ... 7223 1931 4427] TEST: [5976 5964 2905 ... 9084 1706 3812]
# TRAIN: [3105 6176 8269 ... 7404 3470  612] TEST: [3332 5959 7619 ... 8717 8505  161]
# TRAIN: [5637 3763 1055 ... 8726 3733 6524] TEST: [1977  783 7055 ... 1020 6577 9448]
# TRAIN: [7975 9434 7278 ... 1981 6672 5054] TEST: [4688 5923 7343 ...  319 2838 2823]
# TRAIN: [6873  710 3760 ... 2512 2784 6164] TEST: [4830 7217 1976 ...  666 9036  226]
# TRAIN: [2900 5545   25 ... 4134 5466 3201] TEST: [9676 6344 7637 ... 7230 4326  859]
# TRAIN: [3148 9020 9511 ...   52 2496   40] TEST: [6162 8145 6597 ... 3883  240 6811]
# TRAIN: [7257  834 9856 ... 8972 2842  150] TEST: [3424 1952 2399 ... 4911 7340 2585]
# TRAIN: [  34 2548  178 ... 3866 7925 7115] TEST: [1359 4810 2039 ... 2903 2398 2450]
# TRAIN: [ 623 4475  782 ... 3856 6849 4641] TEST: [6933 1952  110 ... 3920  347 6533]
# TRAIN: [ 793 2627 5433 ... 9131  950 3110] TEST: [1291 3270 4517 ... 2207 4317   90]
# TRAIN: [9419 1084 5756 ... 1588 8717 6565] TEST: [8708  982 5973 ... 4456 1822 2304]
# TRAIN: [ 139  534 8087 ...  286 1214 8444] TEST: [2633 9081 4410 ... 8181 9570  462]
# TRAIN: [4229  500 7553 ... 7837 7852 6409] TEST: [ 654 6337 1987 ... 1623  538 6834]
# TRAIN: [4155 9326 2187 ... 2826 4415 1595] TEST: [8813 4395 5620 ... 4343 7986 4051]
# TRAIN: [7121  364 3680 ... 1757 1352 8572] TEST: [2526 9441  314 ... 3113 2574 6501]
# TRAIN: [5377 5108 6386 ... 2098 6141 8728] TEST: [ 484 2765 5338 ...  753 7251 8146]
# TRAIN: [3193 4627 1699 ...  147 6052 3348] TEST: [7436 5705 2198 ... 8165 5304 8774]
# TRAIN: [3194 5561 3229 ... 6266 5205 7417] TEST: [ 480 2280 1846 ... 7095 4755 3510]
# TRAIN: [7133 2122 7387 ... 2138 4640 7264] TEST: [9902 3256 6547 ... 4999 9105 9448]
# TRAIN: [8023 4647   55 ... 2829 3780 2750] TEST: [4965 6944 3817 ... 7367 6744 1512]
# TRAIN: [9510 7392 3701 ... 8407 7085 6656] TEST: [1266 2081 4056 ... 9374 7112 5263]
# TRAIN: [7790 5922 1051 ... 2145 2284 8608] TEST: [8453  167 1311 ... 7020 5844 2347]
# TRAIN: [4468 4659 8565 ... 5618 3547  667] TEST: [6974 7318 6384 ... 3754 2180 8069]
# TRAIN: [5957 3089 2795 ... 2577 9036 6481] TEST: [9738 2049 9862 ... 8489 6703 5020]
# TRAIN: [8092 5047 2895 ... 5172 5320 6948] TEST: [9945 1251 4076 ... 6376 5970 1676]
# TRAIN: [2903 5942 6395 ... 7909 6684 4718] TEST: [7318 1091 9642 ... 6083 5223 8558]
# TRAIN: [1076 4445 5655 ... 2784 2617 7903] TEST: [4410 1083 3186 ... 2746 4829 2957]
# TRAIN: [4704 3799 4626 ... 1788 8510 2530] TEST: [5996 9799 1302 ... 1746 4433 1261]
# TRAIN: [5152 7211 6665 ... 9916 5545 5154] TEST: [2673 5410 2495 ... 6906 4601 1104]
# TRAIN: [5580 9115 8748 ... 1803  818 6551] TEST: [8388 4640 5649 ... 9100 9338 1921]
# TRAIN: [ 253 7375 6143 ... 7306 5961 6623] TEST: [9954 8933  787 ...  589 5427 2074]
# TRAIN: [9256 4325 9410 ... 7841 6378 9244] TEST: [5529  452 4042 ... 6931 7353  930]
# TRAIN: [8105 6353 3869 ... 2879 2445 9888] TEST: [7711 4981 9963 ... 6177 9238 9181]
# TRAIN: [2904 5769 5361 ... 5480 6478 9812] TEST: [7874 8754 2491 ... 2600 6872 9838]
# TRAIN: [1365 2143 1558 ... 3744 2830 9543] TEST: [8693 3536 2723 ... 7754 2595 5621]
# TRAIN: [9774 8088 7449 ... 2256 9656 7788] TEST: [5361 8549 3682 ... 8598 9235 4620]
# TRAIN: [6480 1154 7510 ...   84 3494 7804] TEST: [5618 3384 7812 ... 3780  473  815]
# TRAIN: [9646 2902 9616 ... 7467 5282 8523] TEST: [3171 9671 1141 ...  850 2613 9468]
# TRAIN: [2992 9935  751 ... 2851 6037 1122] TEST: [ 325 6165 9053 ... 9422 3340 6473]
# TRAIN: [9645 8022 4071 ... 1869 6731 1890] TEST: [2873 4243 5241 ... 1048 6006 7713]
# TRAIN: [ 971 6498 6508 ... 4211 5570 5412] TEST: [1017 4795 5102 ... 3462 6914 6412]
# TRAIN: [7673 6832 9251 ... 4334 4218 6755] TEST: [1554 5072 9741 ... 9321 8903 3815]
# TRAIN: [9090 1055 6458 ... 9764 2271 6255] TEST: [9529  420 9850 ... 3634 3197 3485]
# TRAIN: [ 732 4416  682 ... 9991  249 2234] TEST: [9251 2259 9876 ...  805 9773 4521]
# TRAIN: [6408 1490 5890 ... 2458 1425  873] TEST: [2403 6042 8898 ... 9076 9309 5465]
# TRAIN: [5161  844  160 ... 9248 6154 2179] TEST: [1358 3169 2143 ... 9734 7275 1521]

# %%
decision_trees = list()
dt_test_scores = list()
count = 0

for train_index, test_index in moons.split(X):
    count = count + 1
    ##Spliting the test and train
    X_train = X[train_index]
    y_train = y[train_index]
    X_test = X[test_index]
    y_test = y[test_index]
    
    ##Initializing the model
    split_tree_clf = DecisionTreeClassifier(max_leaf_nodes = 4)
    
    ##trainign the model
    split_tree_clf.fit(X_train,y_train)
    decision_trees.append(split_tree_clf)
    
    y_pred = tree_moon_clf.predict(X_test)
    print('Tree ',count, ', Accuracy',sum(y_pred == y_test)/len(y_pred))
    dt_test_scores.append(tree_moon_clf.score(X_test, y_test))
# Out:
# Tree  1 , Accuracy 0.8548
# Tree  2 , Accuracy 0.8548
# Tree  3 , Accuracy 0.8488
# Tree  4 , Accuracy 0.846
# Tree  5 , Accuracy 0.8492
# Tree  6 , Accuracy 0.8496
# Tree  7 , Accuracy 0.8504
# Tree  8 , Accuracy 0.858
# Tree  9 , Accuracy 0.8592
# Tree  10 , Accuracy 0.848
# Tree  11 , Accuracy 0.856
# Tree  12 , Accuracy 0.8732
# Tree  13 , Accuracy 0.8636
# Tree  14 , Accuracy 0.8552
# Tree  15 , Accuracy 0.8524
# Tree  16 , Accuracy 0.8336
# Tree  17 , Accuracy 0.8512
# Tree  18 , Accuracy 0.8536
# Tree  19 , Accuracy 0.8472
# Tree  20 , Accuracy 0.8544
# Tree  21 , Accuracy 0.8568
# Tree  22 , Accuracy 0.8424
# Tree  23 , Accuracy 0.8488
# Tree  24 , Accuracy 0.8516
# Tree  25 , Accuracy 0.862
# Tree  26 , Accuracy 0.858
# Tree  27 , Accuracy 0.85
# Tree  28 , Accuracy 0.8568
# Tree  29 , Accuracy 0.8484
# Tree  30 , Accuracy 0.8568
# Tree  31 , Accuracy 0.8512
# Tree  32 , Accuracy 0.8624
# Tree  33 , Accuracy 0.8468
# Tree  34 , Accuracy 0.858
# Tree  35 , Accuracy 0.858
# Tree  36 , Accuracy 0.8708
# Tree  37 , Accuracy 0.8572
# Tree  38 , Accuracy 0.8548
# Tree  39 , Accuracy 0.8436
# Tree  40 , Accuracy 0.8648
# Tree  41 , Accuracy 0.846
# Tree  42 , Accuracy 0.8556
# Tree  43 , Accuracy 0.8536
# Tree  44 , Accuracy 0.852
# Tree  45 , Accuracy 0.8556
# Tree  46 , Accuracy 0.8528
# Tree  47 , Accuracy 0.86
# Tree  48 , Accuracy 0.8572
# Tree  49 , Accuracy 0.8416
# Tree  50 , Accuracy 0.8544
# Tree  51 , Accuracy 0.8576
# Tree  52 , Accuracy 0.8664
# Tree  53 , Accuracy 0.8456
# Tree  54 , Accuracy 0.8564
# Tree  55 , Accuracy 0.856
# Tree  56 , Accuracy 0.8564
# Tree  57 , Accuracy 0.8552
# Tree  58 , Accuracy 0.858
# Tree  59 , Accuracy 0.8516
# Tree  60 , Accuracy 0.858
# Tree  61 , Accuracy 0.8664
# Tree  62 , Accuracy 0.8536
# Tree  63 , Accuracy 0.8584
# Tree  64 , Accuracy 0.8552
# Tree  65 , Accuracy 0.8452
# Tree  66 , Accuracy 0.8624
# Tree  67 , Accuracy 0.8588
# Tree  68 , Accuracy 0.8568
# Tree  69 , Accuracy 0.8524
# Tree  70 , Accuracy 0.848
# Tree  71 , Accuracy 0.8468
# Tree  72 , Accuracy 0.844
# Tree  73 , Accuracy 0.8512
# Tree  74 , Accuracy 0.8548
# Tree  75 , Accuracy 0.8568
# Tree  76 , Accuracy 0.8548
# Tree  77 , Accuracy 0.8548
# Tree  78 , Accuracy 0.8512
# Tree  79 , Accuracy 0.8552
# Tree  80 , Accuracy 0.864
# Tree  81 , Accuracy 0.8484
# Tree  82 , Accuracy 0.862
# Tree  83 , Accuracy 0.8564
# Tree  84 , Accuracy 0.8664
# Tree  85 , Accuracy 0.8564
# Tree  86 , Accuracy 0.8516
# Tree  87 , Accuracy 0.8528
# Tree  88 , Accuracy 0.848
# Tree  89 , Accuracy 0.8576
# Tree  90 , Accuracy 0.852
# Tree  91 , Accuracy 0.8612
# Tree  92 , Accuracy 0.8572
# Tree  93 , Accuracy 0.8616
# Tree  94 , Accuracy 0.8492
# Tree  95 , Accuracy 0.8592
# Tree  96 , Accuracy 0.8712
# Tree  97 , Accuracy 0.8544
# Tree  98 , Accuracy 0.8508
# Tree  99 , Accuracy 0.8544
# Tree  100 , Accuracy 0.8576
# Tree  101 , Accuracy 0.8396
# Tree  102 , Accuracy 0.8624
# Tree  103 , Accuracy 0.8712
# Tree  104 , Accuracy 0.8512
# Tree  105 , Accuracy 0.8552
# Tree  106 , Accuracy 0.8592
# Tree  107 , Accuracy 0.8528
# Tree  108 , Accuracy 0.852
# Tree  109 , Accuracy 0.836
# Tree  110 , Accuracy 0.8548
# Tree  111 , Accuracy 0.862
# Tree  112 , Accuracy 0.8596
# Tree  113 , Accuracy 0.8528
# Tree  114 , Accuracy 0.852
# Tree  115 , Accuracy 0.852
# Tree  116 , Accuracy 0.8536
# Tree  117 , Accuracy 0.8532
# Tree  118 , Accuracy 0.8536
# Tree  119 , Accuracy 0.8588
# Tree  120 , Accuracy 0.8592
# Tree  121 , Accuracy 0.856
# Tree  122 , Accuracy 0.846
# Tree  123 , Accuracy 0.8484
# Tree  124 , Accuracy 0.8588
# Tree  125 , Accuracy 0.8608
# Tree  126 , Accuracy 0.8504
# Tree  127 , Accuracy 0.8504
# Tree  128 , Accuracy 0.8568
# Tree  129 , Accuracy 0.8512
# Tree  130 , Accuracy 0.8584
# Tree  131 , Accuracy 0.8604
# Tree  132 , Accuracy 0.842
# Tree  133 , Accuracy 0.8516
# Tree  134 , Accuracy 0.8564
# Tree  135 , Accuracy 0.8524
# Tree  136 , Accuracy 0.8552
# Tree  137 , Accuracy 0.8476
# Tree  138 , Accuracy 0.8552
# Tree  139 , Accuracy 0.86
# Tree  140 , Accuracy 0.8624
# Tree  141 , Accuracy 0.8644
# Tree  142 , Accuracy 0.856
# Tree  143 , Accuracy 0.862
# Tree  144 , Accuracy 0.8596
# Tree  145 , Accuracy 0.8516
# Tree  146 , Accuracy 0.8576
# Tree  147 , Accuracy 0.85
# Tree  148 , Accuracy 0.8644
# Tree  149 , Accuracy 0.8508
# Tree  150 , Accuracy 0.856
# Tree  151 , Accuracy 0.8584
# Tree  152 , Accuracy 0.86
# Tree  153 , Accuracy 0.8628
# Tree  154 , Accuracy 0.8552
# Tree  155 , Accuracy 0.8572
# Tree  156 , Accuracy 0.8564
# Tree  157 , Accuracy 0.8468
# Tree  158 , Accuracy 0.852
# Tree  159 , Accuracy 0.8536
# Tree  160 , Accuracy 0.8476
# Tree  161 , Accuracy 0.8552
# Tree  162 , Accuracy 0.8596
# Tree  163 , Accuracy 0.8528
# Tree  164 , Accuracy 0.8612
# Tree  165 , Accuracy 0.8464
# Tree  166 , Accuracy 0.862
# Tree  167 , Accuracy 0.8508
# Tree  168 , Accuracy 0.856
# Tree  169 , Accuracy 0.8464
# Tree  170 , Accuracy 0.8576
# Tree  171 , Accuracy 0.8552
# Tree  172 , Accuracy 0.8556
# Tree  173 , Accuracy 0.8536
# Tree  174 , Accuracy 0.8572
# Tree  175 , Accuracy 0.8564
# Tree  176 , Accuracy 0.868
# Tree  177 , Accuracy 0.8536
# Tree  178 , Accuracy 0.8536
# Tree  179 , Accuracy 0.8592
# Tree  180 , Accuracy 0.8588
# Tree  181 , Accuracy 0.8556
# Tree  182 , Accuracy 0.8532
# Tree  183 , Accuracy 0.8492
# Tree  184 , Accuracy 0.8576
# Tree  185 , Accuracy 0.8608
# Tree  186 , Accuracy 0.8616
# Tree  187 , Accuracy 0.8628
# Tree  188 , Accuracy 0.8476
# Tree  189 , Accuracy 0.8468
# Tree  190 , Accuracy 0.8556
# Tree  191 , Accuracy 0.858
# Tree  192 , Accuracy 0.8688
# Tree  193 , Accuracy 0.8464
# Tree  194 , Accuracy 0.8528
# Tree  195 , Accuracy 0.8624
# Tree  196 , Accuracy 0.8536
# Tree  197 , Accuracy 0.856
# Tree  198 , Accuracy 0.8428
# Tree  199 , Accuracy 0.8524
# Tree  200 , Accuracy 0.854
# Tree  201 , Accuracy 0.8616
# Tree  202 , Accuracy 0.8536
# Tree  203 , Accuracy 0.8464
# Tree  204 , Accuracy 0.8524
# Tree  205 , Accuracy 0.8592
# Tree  206 , Accuracy 0.8584
# Tree  207 , Accuracy 0.852
# Tree  208 , Accuracy 0.86
# Tree  209 , Accuracy 0.8592
# Tree  210 , Accuracy 0.8552
# Tree  211 , Accuracy 0.8564
# Tree  212 , Accuracy 0.8588
# Tree  213 , Accuracy 0.8632
# Tree  214 , Accuracy 0.8584
# Tree  215 , Accuracy 0.8516
# Tree  216 , Accuracy 0.8488
# Tree  217 , Accuracy 0.852
# Tree  218 , Accuracy 0.8568
# Tree  219 , Accuracy 0.8592
# Tree  220 , Accuracy 0.8528
# Tree  221 , Accuracy 0.8472
# Tree  222 , Accuracy 0.862
# Tree  223 , Accuracy 0.8416
# Tree  224 , Accuracy 0.8616
# Tree  225 , Accuracy 0.8576
# Tree  226 , Accuracy 0.8576
# Tree  227 , Accuracy 0.8592
# Tree  228 , Accuracy 0.852
# Tree  229 , Accuracy 0.8576
# Tree  230 , Accuracy 0.8624
# Tree  231 , Accuracy 0.86
# Tree  232 , Accuracy 0.8576
# Tree  233 , Accuracy 0.8508
# Tree  234 , Accuracy 0.8528
# Tree  235 , Accuracy 0.8632
# Tree  236 , Accuracy 0.8564
# Tree  237 , Accuracy 0.8476
# Tree  238 , Accuracy 0.858
# Tree  239 , Accuracy 0.8596
# Tree  240 , Accuracy 0.86
# Tree  241 , Accuracy 0.8488
# Tree  242 , Accuracy 0.8408
# Tree  243 , Accuracy 0.854
# Tree  244 , Accuracy 0.862
# Tree  245 , Accuracy 0.856
# Tree  246 , Accuracy 0.8572
# Tree  247 , Accuracy 0.854
# Tree  248 , Accuracy 0.8588
# Tree  249 , Accuracy 0.8608
# Tree  250 , Accuracy 0.8608
# Tree  251 , Accuracy 0.8568
# Tree  252 , Accuracy 0.8424
# Tree  253 , Accuracy 0.8504
# Tree  254 , Accuracy 0.8656
# Tree  255 , Accuracy 0.8604
# Tree  256 , Accuracy 0.858
# Tree  257 , Accuracy 0.8576
# Tree  258 , Accuracy 0.8648
# Tree  259 , Accuracy 0.8528
# Tree  260 , Accuracy 0.8548
# Tree  261 , Accuracy 0.8532
# Tree  262 , Accuracy 0.8704
# Tree  263 , Accuracy 0.8552
# Tree  264 , Accuracy 0.8496
# Tree  265 , Accuracy 0.8556
# Tree  266 , Accuracy 0.8524
# Tree  267 , Accuracy 0.8604
# Tree  268 , Accuracy 0.8568
# Tree  269 , Accuracy 0.8496
# Tree  270 , Accuracy 0.8592
# Tree  271 , Accuracy 0.8556
# Tree  272 , Accuracy 0.852
# Tree  273 , Accuracy 0.86
# Tree  274 , Accuracy 0.8552
# Tree  275 , Accuracy 0.8636
# Tree  276 , Accuracy 0.8552
# Tree  277 , Accuracy 0.8544
# Tree  278 , Accuracy 0.8532
# Tree  279 , Accuracy 0.8444
# Tree  280 , Accuracy 0.8592
# Tree  281 , Accuracy 0.8532
# Tree  282 , Accuracy 0.8548
# Tree  283 , Accuracy 0.8556
# Tree  284 , Accuracy 0.8576
# Tree  285 , Accuracy 0.8524
# Tree  286 , Accuracy 0.854
# Tree  287 , Accuracy 0.8468
# Tree  288 , Accuracy 0.856
# Tree  289 , Accuracy 0.8476
# Tree  290 , Accuracy 0.8492
# Tree  291 , Accuracy 0.8516
# Tree  292 , Accuracy 0.8504
# Tree  293 , Accuracy 0.8592
# Tree  294 , Accuracy 0.8564
# Tree  295 , Accuracy 0.8416
# Tree  296 , Accuracy 0.862
# Tree  297 , Accuracy 0.8612
# Tree  298 , Accuracy 0.8584
# Tree  299 , Accuracy 0.8596
# Tree  300 , Accuracy 0.8668
# Tree  301 , Accuracy 0.86
# Tree  302 , Accuracy 0.8504
# Tree  303 , Accuracy 0.8612
# Tree  304 , Accuracy 0.8508
# Tree  305 , Accuracy 0.8524
# Tree  306 , Accuracy 0.854
# Tree  307 , Accuracy 0.848
# Tree  308 , Accuracy 0.8568
# Tree  309 , Accuracy 0.8628
# Tree  310 , Accuracy 0.85
# Tree  311 , Accuracy 0.8572
# Tree  312 , Accuracy 0.8644
# Tree  313 , Accuracy 0.8556
# Tree  314 , Accuracy 0.852
# Tree  315 , Accuracy 0.8592
# Tree  316 , Accuracy 0.8624
# Tree  317 , Accuracy 0.852
# Tree  318 , Accuracy 0.8668
# Tree  319 , Accuracy 0.8516
# Tree  320 , Accuracy 0.8664
# Tree  321 , Accuracy 0.85
# Tree  322 , Accuracy 0.8548
# Tree  323 , Accuracy 0.8548
# Tree  324 , Accuracy 0.8464
# Tree  325 , Accuracy 0.8568
# Tree  326 , Accuracy 0.8564
# Tree  327 , Accuracy 0.8504
# Tree  328 , Accuracy 0.8532
# Tree  329 , Accuracy 0.8536
# Tree  330 , Accuracy 0.8516
# Tree  331 , Accuracy 0.8532
# Tree  332 , Accuracy 0.86
# Tree  333 , Accuracy 0.852
# Tree  334 , Accuracy 0.8632
# Tree  335 , Accuracy 0.858
# Tree  336 , Accuracy 0.8468
# Tree  337 , Accuracy 0.8548
# Tree  338 , Accuracy 0.8452
# Tree  339 , Accuracy 0.852
# Tree  340 , Accuracy 0.8596
# Tree  341 , Accuracy 0.856
# Tree  342 , Accuracy 0.8492
# Tree  343 , Accuracy 0.8672
# Tree  344 , Accuracy 0.8616
# Tree  345 , Accuracy 0.8472
# Tree  346 , Accuracy 0.8664
# Tree  347 , Accuracy 0.8568
# Tree  348 , Accuracy 0.8456
# Tree  349 , Accuracy 0.8552
# Tree  350 , Accuracy 0.8516
# Tree  351 , Accuracy 0.8504
# Tree  352 , Accuracy 0.8716
# Tree  353 , Accuracy 0.8504
# Tree  354 , Accuracy 0.86
# Tree  355 , Accuracy 0.856
# Tree  356 , Accuracy 0.8496
# Tree  357 , Accuracy 0.864
# Tree  358 , Accuracy 0.856
# Tree  359 , Accuracy 0.8576
# Tree  360 , Accuracy 0.8484
# Tree  361 , Accuracy 0.85
# Tree  362 , Accuracy 0.8492
# Tree  363 , Accuracy 0.8572
# Tree  364 , Accuracy 0.8412
# Tree  365 , Accuracy 0.8564
# Tree  366 , Accuracy 0.8468
# Tree  367 , Accuracy 0.862
# Tree  368 , Accuracy 0.8464
# Tree  369 , Accuracy 0.8628
# Tree  370 , Accuracy 0.862
# Tree  371 , Accuracy 0.8572
# Tree  372 , Accuracy 0.844
# Tree  373 , Accuracy 0.8564
# Tree  374 , Accuracy 0.854
# Tree  375 , Accuracy 0.868
# Tree  376 , Accuracy 0.858
# Tree  377 , Accuracy 0.85
# Tree  378 , Accuracy 0.858
# Tree  379 , Accuracy 0.8576
# Tree  380 , Accuracy 0.8576
# Tree  381 , Accuracy 0.8504
# Tree  382 , Accuracy 0.8632
# Tree  383 , Accuracy 0.8556
# Tree  384 , Accuracy 0.844
# Tree  385 , Accuracy 0.8548
# Tree  386 , Accuracy 0.8608
# Tree  387 , Accuracy 0.8516
# Tree  388 , Accuracy 0.8556
# Tree  389 , Accuracy 0.8648
# Tree  390 , Accuracy 0.854
# Tree  391 , Accuracy 0.8572
# Tree  392 , Accuracy 0.8516
# Tree  393 , Accuracy 0.86
# Tree  394 , Accuracy 0.8552
# Tree  395 , Accuracy 0.846
# Tree  396 , Accuracy 0.8652
# Tree  397 , Accuracy 0.862
# Tree  398 , Accuracy 0.8596
# Tree  399 , Accuracy 0.8592
# Tree  400 , Accuracy 0.8528
# Tree  401 , Accuracy 0.864
# Tree  402 , Accuracy 0.8588
# Tree  403 , Accuracy 0.8592
# Tree  404 , Accuracy 0.8524
# Tree  405 , Accuracy 0.8492
# Tree  406 , Accuracy 0.856
# Tree  407 , Accuracy 0.85
# Tree  408 , Accuracy 0.8488
# Tree  409 , Accuracy 0.8608
# Tree  410 , Accuracy 0.8548
# Tree  411 , Accuracy 0.8512
# Tree  412 , Accuracy 0.8496
# Tree  413 , Accuracy 0.8512
# Tree  414 , Accuracy 0.8516
# Tree  415 , Accuracy 0.8572
# Tree  416 , Accuracy 0.866
# Tree  417 , Accuracy 0.8452
# Tree  418 , Accuracy 0.8584
# Tree  419 , Accuracy 0.8612
# Tree  420 , Accuracy 0.8552
# Tree  421 , Accuracy 0.8556
# Tree  422 , Accuracy 0.8512
# Tree  423 , Accuracy 0.856
# Tree  424 , Accuracy 0.8664
# Tree  425 , Accuracy 0.8528
# Tree  426 , Accuracy 0.8576
# Tree  427 , Accuracy 0.844
# Tree  428 , Accuracy 0.8544
# Tree  429 , Accuracy 0.8512
# Tree  430 , Accuracy 0.8624
# Tree  431 , Accuracy 0.8476
# Tree  432 , Accuracy 0.8528
# Tree  433 , Accuracy 0.852
# Tree  434 , Accuracy 0.8592
# Tree  435 , Accuracy 0.858
# Tree  436 , Accuracy 0.8524
# Tree  437 , Accuracy 0.8524
# Tree  438 , Accuracy 0.8632
# Tree  439 , Accuracy 0.8516
# Tree  440 , Accuracy 0.8564
# Tree  441 , Accuracy 0.8644
# Tree  442 , Accuracy 0.858
# Tree  443 , Accuracy 0.8636
# Tree  444 , Accuracy 0.8536
# Tree  445 , Accuracy 0.8524
# Tree  446 , Accuracy 0.8568
# Tree  447 , Accuracy 0.8636
# Tree  448 , Accuracy 0.8456
# Tree  449 , Accuracy 0.8464
# Tree  450 , Accuracy 0.8408
# Tree  451 , Accuracy 0.8544
# Tree  452 , Accuracy 0.8568
# Tree  453 , Accuracy 0.8516
# Tree  454 , Accuracy 0.858
# Tree  455 , Accuracy 0.8592
# Tree  456 , Accuracy 0.8656
# Tree  457 , Accuracy 0.8592
# Tree  458 , Accuracy 0.846
# Tree  459 , Accuracy 0.8564
# Tree  460 , Accuracy 0.8524
# Tree  461 , Accuracy 0.862
# Tree  462 , Accuracy 0.854
# Tree  463 , Accuracy 0.8572
# Tree  464 , Accuracy 0.8528
# Tree  465 , Accuracy 0.8488
# Tree  466 , Accuracy 0.8532
# Tree  467 , Accuracy 0.8556
# Tree  468 , Accuracy 0.8648
# Tree  469 , Accuracy 0.8576
# Tree  470 , Accuracy 0.8412
# Tree  471 , Accuracy 0.846
# Tree  472 , Accuracy 0.854
# Tree  473 , Accuracy 0.8516
# Tree  474 , Accuracy 0.8576
# Tree  475 , Accuracy 0.8516
# Tree  476 , Accuracy 0.8624
# Tree  477 , Accuracy 0.86
# Tree  478 , Accuracy 0.856
# Tree  479 , Accuracy 0.8628
# Tree  480 , Accuracy 0.872
# Tree  481 , Accuracy 0.852
# Tree  482 , Accuracy 0.8592
# Tree  483 , Accuracy 0.8456
# Tree  484 , Accuracy 0.8464
# Tree  485 , Accuracy 0.8452
# Tree  486 , Accuracy 0.8544
# Tree  487 , Accuracy 0.8548
# Tree  488 , Accuracy 0.8444
# Tree  489 , Accuracy 0.8548
# Tree  490 , Accuracy 0.858
# Tree  491 , Accuracy 0.8556
# Tree  492 , Accuracy 0.8528
# Tree  493 , Accuracy 0.8516
# Tree  494 , Accuracy 0.8584
# Tree  495 , Accuracy 0.8556
# Tree  496 , Accuracy 0.8488
# Tree  497 , Accuracy 0.8548
# Tree  498 , Accuracy 0.8572
# Tree  499 , Accuracy 0.8572
# Tree  500 , Accuracy 0.8536
# Tree  501 , Accuracy 0.8568
# Tree  502 , Accuracy 0.858
# Tree  503 , Accuracy 0.866
# Tree  504 , Accuracy 0.8452
# Tree  505 , Accuracy 0.8584
# Tree  506 , Accuracy 0.8564
# Tree  507 , Accuracy 0.866
# Tree  508 , Accuracy 0.8564
# Tree  509 , Accuracy 0.854
# Tree  510 , Accuracy 0.8576
# Tree  511 , Accuracy 0.8612
# Tree  512 , Accuracy 0.8604
# Tree  513 , Accuracy 0.8444
# Tree  514 , Accuracy 0.8556
# Tree  515 , Accuracy 0.8584
# Tree  516 , Accuracy 0.8572
# Tree  517 , Accuracy 0.8576
# Tree  518 , Accuracy 0.8476
# Tree  519 , Accuracy 0.864
# Tree  520 , Accuracy 0.8492
# Tree  521 , Accuracy 0.8548
# Tree  522 , Accuracy 0.8612
# Tree  523 , Accuracy 0.852
# Tree  524 , Accuracy 0.8412
# Tree  525 , Accuracy 0.8616
# Tree  526 , Accuracy 0.8384
# Tree  527 , Accuracy 0.8496
# Tree  528 , Accuracy 0.8464
# Tree  529 , Accuracy 0.8504
# Tree  530 , Accuracy 0.8608
# Tree  531 , Accuracy 0.8528
# Tree  532 , Accuracy 0.856
# Tree  533 , Accuracy 0.8608
# Tree  534 , Accuracy 0.8596
# Tree  535 , Accuracy 0.8468
# Tree  536 , Accuracy 0.8608
# Tree  537 , Accuracy 0.8628
# Tree  538 , Accuracy 0.8492
# Tree  539 , Accuracy 0.8672
# Tree  540 , Accuracy 0.8536
# Tree  541 , Accuracy 0.8568
# Tree  542 , Accuracy 0.8508
# Tree  543 , Accuracy 0.8564
# Tree  544 , Accuracy 0.858
# Tree  545 , Accuracy 0.8544
# Tree  546 , Accuracy 0.8564
# Tree  547 , Accuracy 0.858
# Tree  548 , Accuracy 0.8588
# Tree  549 , Accuracy 0.854
# Tree  550 , Accuracy 0.8644
# Tree  551 , Accuracy 0.8532
# Tree  552 , Accuracy 0.848
# Tree  553 , Accuracy 0.85
# Tree  554 , Accuracy 0.8636
# Tree  555 , Accuracy 0.8572
# Tree  556 , Accuracy 0.8592
# Tree  557 , Accuracy 0.8532
# Tree  558 , Accuracy 0.85
# Tree  559 , Accuracy 0.8468
# Tree  560 , Accuracy 0.8512
# Tree  561 , Accuracy 0.8484
# Tree  562 , Accuracy 0.8516
# Tree  563 , Accuracy 0.858
# Tree  564 , Accuracy 0.8564
# Tree  565 , Accuracy 0.8552
# Tree  566 , Accuracy 0.8532
# Tree  567 , Accuracy 0.8468
# Tree  568 , Accuracy 0.8552
# Tree  569 , Accuracy 0.862
# Tree  570 , Accuracy 0.8576
# Tree  571 , Accuracy 0.8512
# Tree  572 , Accuracy 0.8536
# Tree  573 , Accuracy 0.8456
# Tree  574 , Accuracy 0.8588
# Tree  575 , Accuracy 0.8444
# Tree  576 , Accuracy 0.8516
# Tree  577 , Accuracy 0.852
# Tree  578 , Accuracy 0.8456
# Tree  579 , Accuracy 0.852
# Tree  580 , Accuracy 0.8628
# Tree  581 , Accuracy 0.8396
# Tree  582 , Accuracy 0.8544
# Tree  583 , Accuracy 0.8368
# Tree  584 , Accuracy 0.8484
# Tree  585 , Accuracy 0.8448
# Tree  586 , Accuracy 0.8548
# Tree  587 , Accuracy 0.8604
# Tree  588 , Accuracy 0.8516
# Tree  589 , Accuracy 0.8492
# Tree  590 , Accuracy 0.8584
# Tree  591 , Accuracy 0.864
# Tree  592 , Accuracy 0.848
# Tree  593 , Accuracy 0.86
# Tree  594 , Accuracy 0.8624
# Tree  595 , Accuracy 0.8532
# Tree  596 , Accuracy 0.8508
# Tree  597 , Accuracy 0.8592
# Tree  598 , Accuracy 0.8584
# Tree  599 , Accuracy 0.8524
# Tree  600 , Accuracy 0.8516
# Tree  601 , Accuracy 0.858
# Tree  602 , Accuracy 0.862
# Tree  603 , Accuracy 0.8472
# Tree  604 , Accuracy 0.8612
# Tree  605 , Accuracy 0.8564
# Tree  606 , Accuracy 0.8572
# Tree  607 , Accuracy 0.86
# Tree  608 , Accuracy 0.86
# Tree  609 , Accuracy 0.854
# Tree  610 , Accuracy 0.848
# Tree  611 , Accuracy 0.8548
# Tree  612 , Accuracy 0.8596
# Tree  613 , Accuracy 0.8552
# Tree  614 , Accuracy 0.85
# Tree  615 , Accuracy 0.8488
# Tree  616 , Accuracy 0.8592
# Tree  617 , Accuracy 0.8528
# Tree  618 , Accuracy 0.8624
# Tree  619 , Accuracy 0.8552
# Tree  620 , Accuracy 0.8592
# Tree  621 , Accuracy 0.8452
# Tree  622 , Accuracy 0.8576
# Tree  623 , Accuracy 0.8604
# Tree  624 , Accuracy 0.8564
# Tree  625 , Accuracy 0.8492
# Tree  626 , Accuracy 0.8588
# Tree  627 , Accuracy 0.8656
# Tree  628 , Accuracy 0.8552
# Tree  629 , Accuracy 0.8572
# Tree  630 , Accuracy 0.8528
# Tree  631 , Accuracy 0.86
# Tree  632 , Accuracy 0.846
# Tree  633 , Accuracy 0.8596
# Tree  634 , Accuracy 0.8476
# Tree  635 , Accuracy 0.8468
# Tree  636 , Accuracy 0.8604
# Tree  637 , Accuracy 0.852
# Tree  638 , Accuracy 0.8612
# Tree  639 , Accuracy 0.8516
# Tree  640 , Accuracy 0.8644
# Tree  641 , Accuracy 0.8476
# Tree  642 , Accuracy 0.8604
# Tree  643 , Accuracy 0.8448
# Tree  644 , Accuracy 0.8528
# Tree  645 , Accuracy 0.8532
# Tree  646 , Accuracy 0.8552
# Tree  647 , Accuracy 0.8524
# Tree  648 , Accuracy 0.8496
# Tree  649 , Accuracy 0.8496
# Tree  650 , Accuracy 0.8604
# Tree  651 , Accuracy 0.8536
# Tree  652 , Accuracy 0.8592
# Tree  653 , Accuracy 0.8552
# Tree  654 , Accuracy 0.8496
# Tree  655 , Accuracy 0.8628
# Tree  656 , Accuracy 0.8564
# Tree  657 , Accuracy 0.8416
# Tree  658 , Accuracy 0.866
# Tree  659 , Accuracy 0.856
# Tree  660 , Accuracy 0.8536
# Tree  661 , Accuracy 0.86
# Tree  662 , Accuracy 0.8476
# Tree  663 , Accuracy 0.8608
# Tree  664 , Accuracy 0.8704
# Tree  665 , Accuracy 0.8588
# Tree  666 , Accuracy 0.8516
# Tree  667 , Accuracy 0.846
# Tree  668 , Accuracy 0.8584
# Tree  669 , Accuracy 0.8576
# Tree  670 , Accuracy 0.8548
# Tree  671 , Accuracy 0.8572
# Tree  672 , Accuracy 0.8528
# Tree  673 , Accuracy 0.8672
# Tree  674 , Accuracy 0.848
# Tree  675 , Accuracy 0.8628
# Tree  676 , Accuracy 0.8432
# Tree  677 , Accuracy 0.8476
# Tree  678 , Accuracy 0.86
# Tree  679 , Accuracy 0.8496
# Tree  680 , Accuracy 0.8628
# Tree  681 , Accuracy 0.8592
# Tree  682 , Accuracy 0.8524
# Tree  683 , Accuracy 0.8532
# Tree  684 , Accuracy 0.8536
# Tree  685 , Accuracy 0.8672
# Tree  686 , Accuracy 0.8492
# Tree  687 , Accuracy 0.8648
# Tree  688 , Accuracy 0.8504
# Tree  689 , Accuracy 0.8652
# Tree  690 , Accuracy 0.8544
# Tree  691 , Accuracy 0.862
# Tree  692 , Accuracy 0.8544
# Tree  693 , Accuracy 0.8616
# Tree  694 , Accuracy 0.8548
# Tree  695 , Accuracy 0.8648
# Tree  696 , Accuracy 0.8576
# Tree  697 , Accuracy 0.8496
# Tree  698 , Accuracy 0.8604
# Tree  699 , Accuracy 0.842
# Tree  700 , Accuracy 0.8684
# Tree  701 , Accuracy 0.8556
# Tree  702 , Accuracy 0.85
# Tree  703 , Accuracy 0.8608
# Tree  704 , Accuracy 0.8644
# Tree  705 , Accuracy 0.8516
# Tree  706 , Accuracy 0.8528
# Tree  707 , Accuracy 0.8616
# Tree  708 , Accuracy 0.852
# Tree  709 , Accuracy 0.8536
# Tree  710 , Accuracy 0.8656
# Tree  711 , Accuracy 0.8584
# Tree  712 , Accuracy 0.8584
# Tree  713 , Accuracy 0.8584
# Tree  714 , Accuracy 0.8608
# Tree  715 , Accuracy 0.8504
# Tree  716 , Accuracy 0.8592
# Tree  717 , Accuracy 0.85
# Tree  718 , Accuracy 0.8524
# Tree  719 , Accuracy 0.8408
# Tree  720 , Accuracy 0.8544
# Tree  721 , Accuracy 0.8504
# Tree  722 , Accuracy 0.8644
# Tree  723 , Accuracy 0.8608
# Tree  724 , Accuracy 0.8456
# Tree  725 , Accuracy 0.8604
# Tree  726 , Accuracy 0.8552
# Tree  727 , Accuracy 0.8636
# Tree  728 , Accuracy 0.8468
# Tree  729 , Accuracy 0.8568
# Tree  730 , Accuracy 0.8528
# Tree  731 , Accuracy 0.8556
# Tree  732 , Accuracy 0.8572
# Tree  733 , Accuracy 0.8496
# Tree  734 , Accuracy 0.864
# Tree  735 , Accuracy 0.8588
# Tree  736 , Accuracy 0.8596
# Tree  737 , Accuracy 0.8604
# Tree  738 , Accuracy 0.8464
# Tree  739 , Accuracy 0.85
# Tree  740 , Accuracy 0.86
# Tree  741 , Accuracy 0.852
# Tree  742 , Accuracy 0.8548
# Tree  743 , Accuracy 0.8572
# Tree  744 , Accuracy 0.8608
# Tree  745 , Accuracy 0.8528
# Tree  746 , Accuracy 0.8508
# Tree  747 , Accuracy 0.8608
# Tree  748 , Accuracy 0.8524
# Tree  749 , Accuracy 0.8532
# Tree  750 , Accuracy 0.8512
# Tree  751 , Accuracy 0.8548
# Tree  752 , Accuracy 0.8628
# Tree  753 , Accuracy 0.8512
# Tree  754 , Accuracy 0.8488
# Tree  755 , Accuracy 0.8472
# Tree  756 , Accuracy 0.8588
# Tree  757 , Accuracy 0.8524
# Tree  758 , Accuracy 0.8592
# Tree  759 , Accuracy 0.8468
# Tree  760 , Accuracy 0.8612
# Tree  761 , Accuracy 0.8488
# Tree  762 , Accuracy 0.8468
# Tree  763 , Accuracy 0.8604
# Tree  764 , Accuracy 0.8428
# Tree  765 , Accuracy 0.8568
# Tree  766 , Accuracy 0.8452
# Tree  767 , Accuracy 0.8524
# Tree  768 , Accuracy 0.8564
# Tree  769 , Accuracy 0.8508
# Tree  770 , Accuracy 0.846
# Tree  771 , Accuracy 0.8544
# Tree  772 , Accuracy 0.848
# Tree  773 , Accuracy 0.8504
# Tree  774 , Accuracy 0.8608
# Tree  775 , Accuracy 0.8596
# Tree  776 , Accuracy 0.8512
# Tree  777 , Accuracy 0.8584
# Tree  778 , Accuracy 0.8584
# Tree  779 , Accuracy 0.856
# Tree  780 , Accuracy 0.8484
# Tree  781 , Accuracy 0.868
# Tree  782 , Accuracy 0.8472
# Tree  783 , Accuracy 0.8596
# Tree  784 , Accuracy 0.8536
# Tree  785 , Accuracy 0.8528
# Tree  786 , Accuracy 0.8592
# Tree  787 , Accuracy 0.862
# Tree  788 , Accuracy 0.8512
# Tree  789 , Accuracy 0.8496
# Tree  790 , Accuracy 0.8588
# Tree  791 , Accuracy 0.8532
# Tree  792 , Accuracy 0.858
# Tree  793 , Accuracy 0.854
# Tree  794 , Accuracy 0.846
# Tree  795 , Accuracy 0.8576
# Tree  796 , Accuracy 0.8596
# Tree  797 , Accuracy 0.846
# Tree  798 , Accuracy 0.8516
# Tree  799 , Accuracy 0.8484
# Tree  800 , Accuracy 0.8516
# Tree  801 , Accuracy 0.8608
# Tree  802 , Accuracy 0.8608
# Tree  803 , Accuracy 0.8492
# Tree  804 , Accuracy 0.8532
# Tree  805 , Accuracy 0.848
# Tree  806 , Accuracy 0.8628
# Tree  807 , Accuracy 0.86
# Tree  808 , Accuracy 0.8556
# Tree  809 , Accuracy 0.8596
# Tree  810 , Accuracy 0.8576
# Tree  811 , Accuracy 0.8576
# Tree  812 , Accuracy 0.8576
# Tree  813 , Accuracy 0.864
# Tree  814 , Accuracy 0.8584
# Tree  815 , Accuracy 0.8524
# Tree  816 , Accuracy 0.8532
# Tree  817 , Accuracy 0.8608
# Tree  818 , Accuracy 0.8536
# Tree  819 , Accuracy 0.8524
# Tree  820 , Accuracy 0.8576
# Tree  821 , Accuracy 0.8492
# Tree  822 , Accuracy 0.8452
# Tree  823 , Accuracy 0.8584
# Tree  824 , Accuracy 0.8488
# Tree  825 , Accuracy 0.854
# Tree  826 , Accuracy 0.8468
# Tree  827 , Accuracy 0.8548
# Tree  828 , Accuracy 0.85
# Tree  829 , Accuracy 0.8576
# Tree  830 , Accuracy 0.862
# Tree  831 , Accuracy 0.8556
# Tree  832 , Accuracy 0.854
# Tree  833 , Accuracy 0.8552
# Tree  834 , Accuracy 0.8436
# Tree  835 , Accuracy 0.8636
# Tree  836 , Accuracy 0.8428
# Tree  837 , Accuracy 0.86
# Tree  838 , Accuracy 0.8592
# Tree  839 , Accuracy 0.8576
# Tree  840 , Accuracy 0.8568
# Tree  841 , Accuracy 0.86
# Tree  842 , Accuracy 0.8624
# Tree  843 , Accuracy 0.8356
# Tree  844 , Accuracy 0.8544
# Tree  845 , Accuracy 0.854
# Tree  846 , Accuracy 0.8548
# Tree  847 , Accuracy 0.8564
# Tree  848 , Accuracy 0.8492
# Tree  849 , Accuracy 0.8656
# Tree  850 , Accuracy 0.8532
# Tree  851 , Accuracy 0.8628
# Tree  852 , Accuracy 0.8548
# Tree  853 , Accuracy 0.854
# Tree  854 , Accuracy 0.856
# Tree  855 , Accuracy 0.8592
# Tree  856 , Accuracy 0.852
# Tree  857 , Accuracy 0.8528
# Tree  858 , Accuracy 0.8456
# Tree  859 , Accuracy 0.8584
# Tree  860 , Accuracy 0.8584
# Tree  861 , Accuracy 0.848
# Tree  862 , Accuracy 0.8512
# Tree  863 , Accuracy 0.8464
# Tree  864 , Accuracy 0.8652
# Tree  865 , Accuracy 0.862
# Tree  866 , Accuracy 0.8524
# Tree  867 , Accuracy 0.8568
# Tree  868 , Accuracy 0.852
# Tree  869 , Accuracy 0.856
# Tree  870 , Accuracy 0.8468
# Tree  871 , Accuracy 0.8604
# Tree  872 , Accuracy 0.8676
# Tree  873 , Accuracy 0.8532
# Tree  874 , Accuracy 0.846
# Tree  875 , Accuracy 0.8568
# Tree  876 , Accuracy 0.8596
# Tree  877 , Accuracy 0.8508
# Tree  878 , Accuracy 0.8436
# Tree  879 , Accuracy 0.8544
# Tree  880 , Accuracy 0.8584
# Tree  881 , Accuracy 0.8476
# Tree  882 , Accuracy 0.8656
# Tree  883 , Accuracy 0.8512
# Tree  884 , Accuracy 0.846
# Tree  885 , Accuracy 0.8496
# Tree  886 , Accuracy 0.8648
# Tree  887 , Accuracy 0.8604
# Tree  888 , Accuracy 0.8528
# Tree  889 , Accuracy 0.866
# Tree  890 , Accuracy 0.8552
# Tree  891 , Accuracy 0.8436
# Tree  892 , Accuracy 0.8544
# Tree  893 , Accuracy 0.8548
# Tree  894 , Accuracy 0.8556
# Tree  895 , Accuracy 0.8532
# Tree  896 , Accuracy 0.8652
# Tree  897 , Accuracy 0.8592
# Tree  898 , Accuracy 0.86
# Tree  899 , Accuracy 0.8552
# Tree  900 , Accuracy 0.8568
# Tree  901 , Accuracy 0.8532
# Tree  902 , Accuracy 0.862
# Tree  903 , Accuracy 0.8628
# Tree  904 , Accuracy 0.8528
# Tree  905 , Accuracy 0.8568
# Tree  906 , Accuracy 0.8572
# Tree  907 , Accuracy 0.8644
# Tree  908 , Accuracy 0.8572
# Tree  909 , Accuracy 0.8456
# Tree  910 , Accuracy 0.8664
# Tree  911 , Accuracy 0.8464
# Tree  912 , Accuracy 0.8568
# Tree  913 , Accuracy 0.8644
# Tree  914 , Accuracy 0.846
# Tree  915 , Accuracy 0.8436
# Tree  916 , Accuracy 0.8516
# Tree  917 , Accuracy 0.85
# Tree  918 , Accuracy 0.8472
# Tree  919 , Accuracy 0.8412
# Tree  920 , Accuracy 0.8528
# Tree  921 , Accuracy 0.8536
# Tree  922 , Accuracy 0.8596
# Tree  923 , Accuracy 0.8472
# Tree  924 , Accuracy 0.8552
# Tree  925 , Accuracy 0.858
# Tree  926 , Accuracy 0.8608
# Tree  927 , Accuracy 0.8596
# Tree  928 , Accuracy 0.8648
# Tree  929 , Accuracy 0.8548
# Tree  930 , Accuracy 0.8492
# Tree  931 , Accuracy 0.8428
# Tree  932 , Accuracy 0.8572
# Tree  933 , Accuracy 0.8536
# Tree  934 , Accuracy 0.8528
# Tree  935 , Accuracy 0.8508
# Tree  936 , Accuracy 0.8452
# Tree  937 , Accuracy 0.8604
# Tree  938 , Accuracy 0.864
# Tree  939 , Accuracy 0.8488
# Tree  940 , Accuracy 0.864
# Tree  941 , Accuracy 0.8476
# Tree  942 , Accuracy 0.8524
# Tree  943 , Accuracy 0.8656
# Tree  944 , Accuracy 0.8564
# Tree  945 , Accuracy 0.8516
# Tree  946 , Accuracy 0.8588
# Tree  947 , Accuracy 0.8512
# Tree  948 , Accuracy 0.852
# Tree  949 , Accuracy 0.8592
# Tree  950 , Accuracy 0.8572
# Tree  951 , Accuracy 0.8476
# Tree  952 , Accuracy 0.8596
# Tree  953 , Accuracy 0.8572
# Tree  954 , Accuracy 0.8396
# Tree  955 , Accuracy 0.8592
# Tree  956 , Accuracy 0.8516
# Tree  957 , Accuracy 0.856
# Tree  958 , Accuracy 0.8508
# Tree  959 , Accuracy 0.848
# Tree  960 , Accuracy 0.8432
# Tree  961 , Accuracy 0.856
# Tree  962 , Accuracy 0.8552
# Tree  963 , Accuracy 0.8576
# Tree  964 , Accuracy 0.8476
# Tree  965 , Accuracy 0.8548
# Tree  966 , Accuracy 0.854
# Tree  967 , Accuracy 0.858
# Tree  968 , Accuracy 0.8408
# Tree  969 , Accuracy 0.8596
# Tree  970 , Accuracy 0.8576
# Tree  971 , Accuracy 0.8564
# Tree  972 , Accuracy 0.8544
# Tree  973 , Accuracy 0.86
# Tree  974 , Accuracy 0.8644
# Tree  975 , Accuracy 0.8604
# Tree  976 , Accuracy 0.8572
# Tree  977 , Accuracy 0.858
# Tree  978 , Accuracy 0.8484
# Tree  979 , Accuracy 0.8556
# Tree  980 , Accuracy 0.8596
# Tree  981 , Accuracy 0.8596
# Tree  982 , Accuracy 0.8416
# Tree  983 , Accuracy 0.86
# Tree  984 , Accuracy 0.8492
# Tree  985 , Accuracy 0.8472
# Tree  986 , Accuracy 0.8496
# Tree  987 , Accuracy 0.856
# Tree  988 , Accuracy 0.8492
# Tree  989 , Accuracy 0.8468
# Tree  990 , Accuracy 0.8556
# Tree  991 , Accuracy 0.8528
# Tree  992 , Accuracy 0.8592
# Tree  993 , Accuracy 0.8596
# Tree  994 , Accuracy 0.8516
# Tree  995 , Accuracy 0.8532
# Tree  996 , Accuracy 0.8552
# Tree  997 , Accuracy 0.8676
# Tree  998 , Accuracy 0.8656
# Tree  999 , Accuracy 0.8544
# Tree  1000 , Accuracy 0.8508

# %%
all_predictions = list()
for tree in decision_trees:
    all_predictions.append(tree.predict(X_test).tolist())

# %%
import numpy as np

trees_preds = np.array(all_predictions)
trees_preds.shape
# Out:
# (1000, 2500)

# %%
from scipy.stats import mode
final_preds, _ = mode(trees_preds, axis=0)

# %%
##Checking the accuracy using final predictions

sum(final_preds.squeeze() == y_test)/len(y_test)
# Out:
# 0.8516
